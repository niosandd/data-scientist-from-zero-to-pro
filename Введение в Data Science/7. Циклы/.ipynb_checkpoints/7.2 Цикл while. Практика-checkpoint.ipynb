# %% [markdown]
# 1. По последним данным, население Торжка в 2020 году составляло 44 439 человек. Постепенно количество местных жителей снижается. Предположим, что с каждым годом население сокращается на 650 человек. Напишите цикл, который выводил бы на печать год и прогнозируемое число жителей Торжка, пока население не уменьшится до 40 тысяч человек.

# %%
population = 44439
year = 2020
while population >= 40000:
    year += 1
    population -= 650
    print(year, population)
# Out:
# 2021 43789
# 2022 43139
# 2023 42489
# 2024 41839
# 2025 41189
# 2026 40539
# 2027 39889

# %% [markdown]
# 2. При помощи цикла `while`, напишите программу, которая просит ввести любое число и выводит в ответ его квадрат. Программа должна повторять это действие бесконечно. Но, если человек вводит число 5, программа выводит на печать «дурак опять» и прекращает работать.

# %%
while True:
    number = float(input('Введите число '))
    if number == 5:
        print('Дурак опять')
        break
    print(number**2)
# Out:
# Введите число  7
# 49.0
# Введите число  9
# 81.0
# Введите число  п
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6209fa4f8419> in <module>
#       1 while True:
# ----> 2     number = float(input('Введите число '))
#       3     if number == 5:
#       4         print('Дурак опять')
#       5         break
#
# ValueError: could not convert string to float: 'п'

# %% [markdown]
# 3. Напишите цикл с использованием `while` – `else`, стартовой точкой которого было бы 25. В каждом прохождении цикла число должно умножаться на 3 и выводиться на печать. Когда число превысит один миллион, цикл должен остановиться, а на печать нужно вывести "стоп".

# %%
# Старт
a = 25

# Цикл
while a <= 1000000:
    a *= 3
    print(a)
else:
    print('Стоп')
# Out:
# 75
# 225
# 675
# 2025
# 6075
# 18225
# 54675
# 164025
# 492075
# 1476225
# Стоп

# %% [markdown]
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# ## Решения

# %% [markdown]
# 1. По последним данным, население Торжка в 2020 году составляло 44 439 человек. Постепенно количество местных жителей снижается. Предположим, что с каждым годом население сокращается на 650 человек. Напишите цикл, который выводил бы на печать год и прогнозируемое число жителей Торжка, пока население не уменьшится до 40 тысяч человек.

# %%
population = 44439
year = 2020
while population >= 40000:
    year += 1
    population -= 650
    print(year, population)
# Out:
# 2021 43789
# 2022 43139
# 2023 42489
# 2024 41839
# 2025 41189
# 2026 40539
# 2027 39889

# %% [markdown]
# 2. При помощи цикла `while`, напишите программу, которая просит ввести любое число и выводит в ответ его квадрат. Программа должна повторять это действие бесконечно. Но, если человек вводит число 5, программа выводит на печать «дурак опять» и прекращает работать.

# %%
while True:
    number = float(input('Введите число '))
    if number == 5:
        print('Дурак опять')
        break
    print(number**2)
# Out:
# Введите число 44
# 1936.0
# Введите число 24
# 576.0
# Введите число 5
# Дурак опять

# %% [markdown]
# 3. Напишите цикл с использованием `while` – `else`, стартовой точкой которого было бы 25. В каждом прохождении цикла число должно умножаться на 3 и выводиться на печать. Когда число превысит один миллион, цикл должен остановиться, а на печать нужно вывести "стоп".

# %%
# Старт
a = 25

# Цикл
while a <= 1000000:
    a *= 3
    print(a)
else:
    print('Стоп')
# Out:
# 75
# 225
# 675
# 2025
# 6075
# 18225
# 54675
# 164025
# 492075
# 1476225
# Стоп
