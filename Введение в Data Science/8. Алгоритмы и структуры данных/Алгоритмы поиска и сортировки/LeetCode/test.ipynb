# %%
nums = [3,2,4]
target = 6

# %%
for i in range(len(nums)):
    for j in range(len(nums)):
        if nums[i] + nums[j] == target:
            print(nums[i], nums[j])
# Out:
# 3 3
# 2 4
# 4 2

# %%
def TwoSum()
for i in range(len(nums)):
    if nums[i] + nums[j] == target:
        print(nums[i], nums[j])
# Out:
# 2 4

# %%
def twoSum(nums, target):
        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                if nums[i] + nums[j] == target:
                    return [i, j]
                
twoSum(nums, target)
# Out:
# [1, 2]

# %%
x = -121
new_x = []
result = []
new_x.append(str(x))

for digit in str(new_x[0]):
    result.append(int(digit))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-438aceb25cf7> in <module>
#       5
#       6 for digit in str(new_x[0]):
# ----> 7     result.append(int(digit))
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
if result == result[::-1]:
    print('True')
else:
    print('False')
# Out:
# True

# %%
# class Solution(object):
#     def isPalindrome(self, x):
#         new_x = []

# %%
new_x = []
new_x = new_x.append(str(x))
print(new_x)
# Out:
# None

# %%
x = -121

# %%
class Solution:
    def isPalindrome(self, x):
        if x < 0:
            return False
        s = str(x)
        return s == s[::-1]
    
sol = Solution()

# %%
sol.isPalindrome(-121)
# Out:
# False
