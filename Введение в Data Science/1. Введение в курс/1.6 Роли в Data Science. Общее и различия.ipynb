# %% [markdown]
# Три рассмотренные профессии — способ разделять сложные задачи Data Science на части и выполнять их более эффективно. Это не иерархия навыков. Специальности существуют параллельно, но часто встречаются переходы из одной в другую.
#
# Взаимодействие в команде:

# %% [markdown]
# ![1643714543262.png](attachment:20cb0fd2-2e0b-4ec0-9fae-282986ddb229.png)

# %% [markdown]
# ![Снимок экрана 2026-07-16 104530.png](attachment:3d60e230-143b-4f1e-8644-583c150491b2.png)

# %% [markdown]
# Компетенции дата-аналитика, ML-инженера и дата-инженера:

# %% [markdown]
# ![1643714628415.png](attachment:8de9ed10-444e-4ec2-ba71-4c222e45853d.png)
