# %% [markdown]
# Три роли в Data Science:
# + Data Analyst (DA);
# + Machine Learning Engineer;
# + Data Engineer (DE).

# %% [markdown]
# Причины изучать Data Science
# 1. Рост спроса на специалистов.

# %% [markdown]
# ![LKh-lFiugxuAzJgYe9KQPZj9lGuTThzk954MJXoPdS-oOmiRWIAmedA6hD1-MYaHO34hnvgE0qbAn0yPoZmXrnyYbfxQ3VjN39TMrD9RRsNbqTIJc3UJkVAMOcwNXchiT.jpg](attachment:8c333753-15a1-4499-8fd4-712a925ddcf9.jpg)

# %% [markdown]
# Популярность Data Scientist — Google Trends
#
# + https://trends.google.com/trends/explore?date=all&q=data%20scientist

# %% [markdown]
# 2. Рост количества данных в мире.

# %% [markdown]
# ![tw5W1SsRHMzARydXffeARm0w93cI6Guv3PYvjzINgytENX-kZRHJc77Ma-XYGNDmouMuMHsi0QA5zVoWubObWTVMESnAlBpZpw--nlV1-6k6MCkFvFjJqwe2BfoeYb9u0.jpg](attachment:7980c2c8-301a-46cb-8e44-d3f7413a5b1b.jpg)

# %% [markdown]
# Дополнительные источники:
# + Зеттабайт — Википедия;
# + Информационный взрыв — Википедия;
#
#
# + https://ru.wikipedia.org/wiki/%D0%97%D0%B5%D1%82%D1%82%D0%B0%D0%B1%D0%B0%D0%B9%D1%82
# + https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%B2%D0%B7%D1%80%D1%8B%D0%B2#:~:text=%D0%97%D0%B0%20%D0%BF%D1%8F%D1%82%D1%8C%20%D0%BF%D1%80%D0%B5%D0%B4%D1%8B%D0%B4%D1%83%D1%89%D0%B8%D1%85%20%D0%BB%D0%B5%D1%82%20%D1%87%D0%B5%D0%BB%D0%BE%D0%B2%D0%B5%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%BE%D0%BC,5%E2%88%99108%20%D0%B1%D0%B0%D0%B9%D1%82

# %% [markdown]
# 3. Рост вычислительных мощностей.
#
# Закон Мура (упрощённо): вычислительная мощность микропроцессоров удваивается каждые два года.

# %% [markdown]
# ![Moores_Law_The_number_of_transistors_on_microchips_doubles_every_two_years.jpg](attachment:17b2f868-628a-4ead-960d-63cbe2b1437b.jpg)

# %% [markdown]
# Дополнительные источники:
#
# + Закон Мура — Википедия;
# + 50 лет закону Мура — Habr;
# + Графические процессоры в решении современных IT-задач — статья Selectel.
#
#
# + https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%BA%D0%BE%D0%BD_%D0%9C%D1%83%D1%80%D0%B0
# + https://habr.com/ru/post/374943/
# + https://selectel.ru/blog/gpu-for-business/#:~:text=GPU%20%D0%BF%D1%80%D0%B8%D0%BC%D0%B5%D0%BD%D1%8F%D0%B5%D1%82%D1%81%D1%8F%20%D0%B2%20%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B8%D1%85%20%D0%B8%D0%B3%D1%80%D0%BE%D0%B2%D1%8B%D1%85,%D0%B3%D0%BB%D1%83%D0%B1%D0%B6%D0%B5%20%D0%B2%20%D0%BD%D0%B0%D1%88%D1%83%20%D0%BF%D0%BE%D0%B2%D1%81%D0%B5%D0%B4%D0%BD%D0%B5%D0%B2%D0%BD%D1%83%D1%8E%20%D0%B6%D0%B8%D0%B7%D0%BD%D1%8C
