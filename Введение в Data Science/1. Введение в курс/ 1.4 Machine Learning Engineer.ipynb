# %% [markdown]
# Machine Learning Engineer / Data Scientist — строит модели машинного обучения (ML).
#
# Компетенции ML-инженера:

# %% [markdown]
# ![1643713062249.png](attachment:bfdc6f1a-f826-4e8a-b1c8-05cba106b6f5.png)

# %% [markdown]
# ML-исследователь (researcher) — отдельная разновидность ML-инженера. Он изобретает новые алгоритмы, строит новые архитектуры нейронных сетей и пишет научные статьи.
#
# Примеры работы ML-инженеров:
#
# 1. Голосовые ассистенты.
# + Распознавание речи: очень краткий вводный курс — Habr;
# + История голосового управления: когда мы начали пытаться говорить с машинами и как они научились нас слышать — vc.ru;
# + Из голоса — в текст: как речевые технологии совершенствуют медицину — vc.ru.
#
# 2. Борьба с незаконной вырубкой леса с помощью ML-моделей.
# + Можно ли спасти дождевой лес, прислушиваясь к нему? — Статья Google и Видео;
# + Social Good — Wikipedia.
# 3. Компьютерное зрение (Computer Vision — CV).
# 4. Обработка естественного языка (Natural Language Processing — NLP).
