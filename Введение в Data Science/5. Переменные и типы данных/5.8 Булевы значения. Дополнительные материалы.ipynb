# %% [markdown]
# На уроке мы разбирали логические операторы `and`, `or`, `not` и какие значения они возвращают, когда соединяют `True` и `False`. Давайте рассмотрим все эти варианты вживую.
#
# Вы можете запустить каждую ячейку и посмотреть, что получится. Попробуйте объяснить, почему выводится тот или иной результат.

# %% [markdown]
# ## and

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ## or

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ## not

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ## Усложняем, придумываем своё, развлекаемся
#
# Попробуйте запустить более сложные сочетания ниже, а также написать свои варианты сочетаний и понять, как это работает.

# %%
True and not False
# Out:
# True

# %%
not True and not False
# Out:
# False

# %%
not True or not False
# Out:
# True

# %%
True and (True or False)
# Out:
# True

# %%
not (True or False) and False
# Out:
# False
