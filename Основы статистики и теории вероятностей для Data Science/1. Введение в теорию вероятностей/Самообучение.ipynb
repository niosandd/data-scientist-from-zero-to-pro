# %% [markdown]
# ![image.png](attachment:d51a9307-ae3e-4862-8ed3-2ffe23e30ecd.png)

# %% [markdown]
# ![image.png](attachment:9b6f8276-2a40-4999-b04a-43772e31c403.png)

# %% [markdown]
# ![image.png](attachment:4fa4946d-ac21-401a-aedb-90af446d3796.png)

# %% [markdown]
# ![image.png](attachment:2464fea0-adba-436e-b0b1-840f46572edd.png)

# %% [markdown]
# ![image.png](attachment:59baf675-4ad2-4829-908f-56c0ba1c7ec3.png)

# %% [markdown]
# ![image.png](attachment:47097f1f-c722-46bb-9cb5-f328ae4c8fca.png)

# %% [markdown]
# ![image.png](attachment:ac0bb520-6e5a-4d9e-8dce-af5a04fe7f24.png)

# %% [markdown]
# ![image.png](attachment:34542810-6088-4cbd-ad1c-e8830a16c290.png)

# %%
# Всё верно.

# Задача 1
# Всего вариантов 2, либо орел, либо решка. Если нам нужна решка, то нужен всего 1 вариант. Соответственно вероятность составляет всего 1/2, то есть 0,5

# Задача 2
# В кубике всего 6 граней. Грани - 1, 2, 3, 4, 5, 6.
# Соответственно, если нам нужна только 3, то это 1 грань, и это 1/6, то есть ее вероятность составляет 0,16

# Задача 3
# Карандашей в коробке всего 10
# Синих всего составляет 3
# Вероятность того, что будет синий, равна 3/10

# Задача 4
# Всего 25 человек
# Юношей 10
# Если нужен юноша, то это составляет 10/25

# Задача 5
# 5/18 - фруктовые 

# Задача 6
# Колода - 36 карт
# Вальтов в колоде всего 4
# 4 / 36

# Задача 7
# 6 / 14

# Задача 8
# 1 + 2 + 3 + 4 - всего 4 грани
# 4 / 6

# Задача 9
# 12 / 20

# Задача 10
# 7 / 50

# %%
# Теоретическая и экспериментальная вероятность
# Событие «или» (объединение)

# %% [markdown]
# ![image.png](attachment:8a0da87c-e3e4-4b47-9a13-c08eb2621539.png)

# %%
# Задача 1
# a) 23 / 40
# б) 1/2

# Задача 2
# a) 8 / 60
# b) 1 /6

# Задача 3
# 9 / 12

# Задача 4
# 4 / 6

# Задача 5
# 12/36

# Задача 6
# a) 14/25
# b) 1/2
# c) 14/25 - 1/2 = 0,6

# Задача 7
# 11 / 15

# Задача 8
# a) 28 / 90
# b) 2 / 6

# %% [markdown]
# ![image.png](attachment:77b706b5-ed17-4972-ba8d-917292b705d4.png)

# %% [markdown]
# ![image.png](attachment:a3769cf1-013c-40ea-84d1-d3b3a5935fe3.png)

# %% [markdown]
# ![image.png](attachment:7f82891a-8eb9-4af2-a0e6-b569d2c2b667.png)

# %% [markdown]
# ![image.png](attachment:2f1bf1fb-7add-4a0a-993f-0a239df729fc.png)

# %% [markdown]
# ![image.png](attachment:9e83019d-5ac6-424e-ae66-8d3225ecd271.png)

# %%
# # Задача 1
# 4/20
# # Задача 2
# 34/27
# # Задача 3
# 4/52
# # Задача 4
# 2 + 1
# 1 + 2
# 2 + 2
# 3/6
# # Задача 5
# 1 2 3 4 5 6
# 1 + 5
# 5 + 1
# 4 + 2
# 2 + 4
# 3 + 3
# # Задача 6
# 7
# # Задача 7
# 2*2*2*2 = 2^4
# # Задача 8
# 6/16
# # Задача 10
# 0,75

# %% [markdown]
# ![image.png](attachment:6631a491-0edd-40c3-92b0-77fccbbe5956.png)

# %%
# 1 - 7 / 20
# 2 - 26 / 38
# 3 - 1 / 52 
# 4 - 4 
# 5 - одинаково
# 6 - сумма 2 и 12
# 7 - 2^5 - 32
# 8 - 10 / 32
# 9 - 2 / 32
# 10 - 1/2 * 1/2 * 1/2 = 1/8 => 1 - 1/8 = ответ

# %% [markdown]
# ![image.png](attachment:97e0eef1-b8a2-4c92-a037-dda70f75bc83.png)

# %% [markdown]
# ![image.png](attachment:8f198c59-8da1-47f7-96b0-5117dce59ffb.png)

# %% [markdown]
# **Есть дерево решений**
#
# https://ru.wikipedia.org/wiki/%D0%94%D0%B5%D1%80%D0%B5%D0%B2%D0%BE_%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B9
#
# ![image.png](attachment:556609bf-75fc-4b6f-a380-a9abdbfc0c9c.png)
#
# Но это можно решать другим образом через основную формулу рекурсии
#
# ![image.png](attachment:6fd79d8d-6b98-4304-8805-478edc1a34de.png)

# %% [markdown]
# ![image.png](attachment:c268113b-8034-4eb2-aa58-9e6c0cc8c7e9.png)

# %% [markdown]
# ![image.png](attachment:ae4a5869-7e1f-4679-8bcd-7d65d7da1b3e.png)

# %% [markdown]
# ![image.png](attachment:50d387c7-4104-4666-97fa-dc20ecd712e1.png)
