# %% [markdown]
# ![image.png](attachment:1d61a4a8-db20-46ba-a300-2457c1142d01.png)

# %% [markdown]
# ![image.png](attachment:cf8e30ff-e3ff-438d-8921-7e24559641d6.png)

# %% [markdown]
# ![image.png](attachment:91917264-b80d-4e31-a076-0f26e3c01a0b.png)

# %% [markdown]
# ![image.png](attachment:d8530fa7-9f20-4351-a415-fc5016dc06e6.png)

# %% [markdown]
# На столе лежит четыре яблока, шесть апельсинов и десять груш. Катя берёт наугад один из этих фруктов. Найдите вероятность того, что выбранным Катей фруктом окажется яблоко.

# %%
4 + 6 + 10
# Out:
# 20

# %%
# P(Я) = 4/20
4/20
# Out:
# 0.2

# %% [markdown]
# В европейской рулетке из 37 секторов есть понятие «уличной ставки» (Street) — когда игрок ставит на выпадение одного из трёх определённых чисел. Какова вероятность провала такой ставки?

# %%
(37-3) / 37
# Out:
# 0.918918918918919

# %% [markdown]
# Найдите вероятность вытащить валета в колоде из 52 игральных карт.

# %%
4 / 52
# Out:
# 0.07692307692307693

# %% [markdown]
# Представьте пару игральных кубиков. Сколько способов существует, чтобы получить четыре в сумме выпавших значений?

# %%
# 3 случая
# 2 + 2
# 3 + 1
# 1 + 3

# %% [markdown]
# Как вы считаете, вероятнее получить на двух кубиках сумму четыре или сумму шесть?
#
# Сравните количество благоприятных исходов для суммы 4 и для 6.

# %%
# Для 4 всего 3
# Для 6 всего пять

# %% [markdown]
# Каково наиболее вероятное значение суммы выпавших значений на двух кубиках?

# %%
# Сумма семь выпадает в шести различных случаях: (1,6), (2,5), (3,4), (4,3), (5,2), (6,1). Все остальные суммы выпадают реже.

# %% [markdown]
# Вы подбрасываете монетку четыре раза. Сколько различных последовательностей (например, орёл-решка-решка-орёл) существует?

# %%
# При каждом броске возможны два исхода. Соответственно при четырёх бросках — 2^4 = 16.

# %% [markdown]
# Какова вероятность получить одинаковое количество решек и орлов, если монетка бросается четыре раза (с учётом порядка подбрасываний)?

# %%
# Благоприятных исходов шесть: ООРР, ОРОР, ОРРО, РРОО, РОРО, РООР. 
# Вероятность события — 6/16 = 0,375

# %% [markdown]
# Какова вероятность получить четыре одинаковых исхода в четырёх бросках монетки?

# %%
# Благоприятных исхода два: ОООО и РРРР. P = 2 / 16 = 0,125

# %% [markdown]
# Решите задачу и найдите вероятность того, что хотя бы один из двух игроков дойдёт до финиша.

# %% [markdown]
# ![image.png](attachment:aa542405-2c75-4ecf-bafd-972bce360e3d.png)
