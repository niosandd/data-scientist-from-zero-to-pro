# %% [markdown]
# ![image.png](attachment:a7d4c850-30c2-4cd0-8e20-da29baa8c395.png)

# %% [markdown]
# ![image.png](attachment:4eed1d16-1a35-486a-ae1b-514f04770304.png)

# %%
# При использовании Prometheus можно дополнительно использовать интеграцию с PagerDuty, и в случае, если мы отключаем node_export (как из тестовой ошибки), в PagerDuty можно ее отфиксировать.

# %% [markdown]
# ![image.png](attachment:9fb5d545-7cd3-4f58-9efe-4fae3371f2a9.png)

# %%
# Добавление дашбордов в Grafana, тестовый case

# %% [markdown]
# ![image.png](attachment:ba11db8e-281e-4401-93f9-7f1f10915016.png)
