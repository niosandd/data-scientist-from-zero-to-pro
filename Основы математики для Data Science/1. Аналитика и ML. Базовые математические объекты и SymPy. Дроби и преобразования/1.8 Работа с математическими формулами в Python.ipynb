# %%
from sympy import *

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x = Symbol('x')

# %%
x**2/2
# Out:
#  2
# x
# --
# 2

# %%
y = Symbol("y")
y
# Out:
# y

# %%
expression = (x**2 - y**2) / (x ** 2 + 2*x*y + y**2)
expression
# Out:
#      2    2
#     x  - y
# ---------------
#  2            2
# x  + 2*x*y + y

# %%
simplify(expression)
# Out:
# x - y
# -----
# x + y
