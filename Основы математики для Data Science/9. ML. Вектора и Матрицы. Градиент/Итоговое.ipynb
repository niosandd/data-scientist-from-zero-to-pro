# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:861e15a5-0d1d-44cb-8913-ec116963f521.png)

# %% [markdown]
# ![image.png](attachment:a89c0b3a-49d1-410a-b7c2-80dcf7acc256.png)

# %%
a = np.array([2, 5, 0, 6, 8, 10, 6, 7, 5, 7])
b = np.array([8, 6, 7, 9, 6, 6, 2, 3, 2, 3])

# %%
(3*a) @ (2*b)
# Out:
# 1632

# %%
np.dot(3*a, 2*b)
# Out:
# 1632

# %% [markdown]
# ![image.png](attachment:603005d7-2641-4f84-b395-cb2e6e6240d7.png)

# %% [markdown]
# ![image.png](attachment:c654da2f-02d9-4eb1-810a-a1b02e22968b.png)

# %%
a = np.array([9, 6, 7, 7, 0, 1, 6, 8, 1, 2])
b = np.array([0, 2, 2, 6, 7, 8, 8, 3, 1, 8])

# %%
(6 * a) @ (5 * b)
# Out:
# 4950

# %%
np.dot(6*a, 5*b)
# Out:
# 4950

# %% [markdown]
# ![image.png](attachment:a480ade6-a736-42a4-a73b-ee318998c2c0.png)

# %%
a = np.array([2, 5, 0, 6, 8, 10, 6, 7, 5, 7])
b = np.array([8, 6, 7, 9, 6, 6, 2, 3, 2, 3])
a @ b
# Out:
# 272

# %%
np.dot(a, b)
# Out:
# 272

# %% [markdown]
# ![image.png](attachment:9a9eb5fe-6de7-4e49-be4d-66415a0bb16e.png)

# %%
a = np.array([9, 6, 7, 7, 0, 1, 6, 8, 1, 2])
b = np.array([0, 2, 2, 6, 7, 8, 8, 3, 1, 8])

# %%
a @ b
# Out:
# 165

# %%
np.dot(a, b)
# Out:
# 165

# %% [markdown]
# ![image.png](attachment:b302ebc7-9994-4d7e-bec6-eb4062113e23.png)

# %%
def transpose(matrix):
    transpose_matrix = np.ndarray(matrix.shape[::-1], matrix.dtype)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            transpose_matrix[j,i] = matrix[i, j]
    return transpose_matrix

# %%
A = np.array(
[[2, 1, 7, 4], 
[5, 6, 7, 3], 
[9, 8, 2, 12], 
[11, 14, 15, 15]], dtype=np.int32
)
A
# Out:
# array([[ 2,  1,  7,  4],
#        [ 5,  6,  7,  3],
#        [ 9,  8,  2, 12],
#        [11, 14, 15, 15]])

# %%
A_T = transpose(A)
A_T
# Out:
# array([[ 2,  5,  9, 11],
#        [ 1,  6,  8, 14],
#        [ 7,  7,  2, 15],
#        [ 4,  3, 12, 15]])

# %%
A = np.array([
    [3, 7, 8, 3, 6], 
    [2, 5, 9, 4, 13]], dtype=np.int32
)
A
# Out:
# array([[ 3,  7,  8,  3,  6],
#        [ 2,  5,  9,  4, 13]])

# %%
A_T = transpose(A)
A_T
# Out:
# array([[ 3,  2],
#        [ 7,  5],
#        [ 8,  9],
#        [ 3,  4],
#        [ 6, 13]])
