# %% [markdown]
# ![image.png](attachment:fabc148e-0229-4bff-b513-c917916a8aec.png)

# %% [markdown]
# ![image.png](attachment:a504c28c-dabe-41b8-96d1-834a37e98de3.png)

# %% [markdown]
# ![image.png](attachment:0fb46529-63ae-4c1c-84ff-1b11662bba23.png)

# %% [markdown]
# ![image.png](attachment:9b986ca3-dd04-4a0d-939d-b2452a9d55d3.png)

# %%
from sympy import *

# %%
# 1.

# %%
# Матрица
A = Matrix([[-2, 4],[3, 7]])
A
# Out:
# Matrix([
# [-2, 4],
# [ 3, 7]])

# %%
# Обратная матрица
A.inv()
# Out:
# Matrix([
# [-7/26, 2/13],
# [ 3/26, 1/13]])

# %%
# 2.

# %%
# Матрица
A = Matrix([[8, 1],[5, 3]])
A
# Out:
# Matrix([
# [8, 1],
# [5, 3]])

# %%
# Обратная матрица
A.inv()
# Out:
# Matrix([
# [ 3/19, -1/19],
# [-5/19,  8/19]])

# %% [markdown]
# ![image.png](attachment:771ff097-6365-48c7-ad81-d73de77aa665.png)

# %%
A = sp.Matrix([[2, 5], [7, -3]])
b = sp.Matrix([11, -23])

print("Определитель:", A.det())
print("Обратная матрица:\n", A.inv())
print("Решение:\n", A.inv() * b)
# Out:
# Определитель: -41
# Обратная матрица:
#  Matrix([[3/41, 5/41], [7/41, -2/41]])
# Решение:
#  Matrix([[-2], [3]])

# %%
A = sp.Matrix([[-3, 1], [3, 5]])
b = sp.Matrix([-2, 8])

print("Определитель:", A.det())
print("Обратная матрица:\n", A.inv())
print("Решение:\n", A.inv() * b)
# Out:
# Определитель: -18
# Обратная матрица:
#  Matrix([[-5/18, 1/18], [1/6, 1/6]])
# Решение:
#  Matrix([[1], [1]])

# %%
A = sp.Matrix([[2, 3], [3, -1]])
b = sp.Matrix([12, 7])

print("Определитель:", A.det())
print("Обратная матрица:\n", A.inv())
print("Решение:\n", A.inv() * b)
# Out:
# Определитель: -11
# Обратная матрица:
#  Matrix([[1/11, 3/11], [3/11, -2/11]])
# Решение:
#  Matrix([[3], [2]])
