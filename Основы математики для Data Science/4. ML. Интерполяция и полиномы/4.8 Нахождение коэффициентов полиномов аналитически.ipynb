# %% [markdown]
# ![image.png](attachment:d94935f1-3e2f-47ee-b906-e1e146328768.png)

# %% [markdown]
# ![image.png](attachment:4ff3f596-3c13-498a-b9bd-74167c62bbb8.png)

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
a2, a1, a0 = symbols('a2,a1,a0')

# %%
eq1_lp = a2 - a1 + a0 + 1
eq2_lp = 4 * a2 + 2 * a1 + a0 - 8
eq3_lp = 4 * a2 - 2*a1 + a0 + 8

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp], [a2, a1, a0])
# Out:
# {(-1, 4, 4)}

# %%
x = Symbol('x')
f = -x**2 + 4*x + 4
f
# Out:
#    2
# - x  + 4*x + 4

# %%
f.subs(x, -1)
# Out:
# -1

# %%
f.subs(x, 2)
# Out:
# 8

# %%
f.subs(x, -2)
# Out:
# -8

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3, 7, num=100)
f = lambda x: -x**2 + 4*x + 4
plt.scatter([-1, 2, -2], [-1, 8, -8], c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))

# %%
# (−2.5,15.0),(−2,10),(−1.5,7.0)

# %%
eq1_lp = 6.25 * a2 - 2.5 * a1 + a0 - 15
eq2_lp = 4 * a2 - 2* a1 + a0 - 10
eq3_lp = 2.25 * a2 - 1.5*a1 + a0 - 7

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp], [a2, a1, a0])
# Out:
# {(4.0, 8.00000000000002, 10.0)}

# %%
x = Symbol('x')
f = 4*x**2 + 8*x + 10.0
f
# Out:
#      2
# - 4*x  + 8*x + 10.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3, 7, num=100)
f = lambda x: 4*x**2 + 8*x + 10.0
plt.scatter([-2.5, -2, -1.5], [15, 10, 7], c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))

# %% [markdown]
# ![image.png](attachment:da02aaa8-5a62-489c-9b88-e6f7c1ca6a04.png)

# %% [markdown]
# ![image.png](attachment:e65065af-0059-436e-b663-cab8482fa388.png)

# %%
a3, a2, a1, a0 = symbols('a3, a2,a1,a0')

# %%
eq1_lp = -0.125 * a3 + 0.25 * a2 - 0.5 * a1 + a0 + 15
eq2_lp = (-1) * a3 + 1 * a2 - 1 * a1 + a0 + 31
eq3_lp = a0 + 7
eq4_lp = 0.125 * a3 + 0.25 * a2 + 0.5 * a1 + a0 + 4

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp], [a3, a2, a1, a0])
# Out:
# {(4.0, -10.0, 10.0, -7.0)}

# %%
x = Symbol('x')
f = 4 * x ** 3 + (-10)*x**2 + 10*x -7
f
# Out:
#    3       2
# 4*x  - 10*x  + 10*x - 7

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3, 7, num=100)
f = lambda x: 4 * x ** 3 + (-10)*x**2 + 10*x -7
plt.scatter([-0.5, -1, 0, 0.5], [-15, -31, -7, -4], c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))
