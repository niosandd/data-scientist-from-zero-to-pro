# %%
# 8.4 Частные производные и минимизация MSE (часть 1)
# 8.5 Частные производные и минимизация MSE (часть 2)
# 8.6 Нахождение производных с помощью sympy

# %% [markdown]
# ![image.png](attachment:053c6216-ce72-476c-8e82-c03f029d9236.png)

# %% [markdown]
# ![image.png](attachment:cbf23208-c897-48ba-8b59-62ae292daed1.png)

# %% [markdown]
# ![image.png](attachment:b9293c14-2595-4573-b12c-37d9bb3e824e.png)

# %% [markdown]
# ![image.png](attachment:b0fd6285-7c91-40f8-bf8b-083e4bec46da.png)

# %%
from sympy import *

# %%
a2, a1, a0 = symbols('a2, a1, a0')

# %%
MSEa2 = 1/3 * (28 * a2 + 5000 * a1 + 12 * a0 - 5000)
MSEa1 = 1/3 * (5000 * a2 + 1090000 * a1 + 2400 * a0 - 1010000)
MSEa0 = 1/3 * (12 * a2 + 2400 * a1 + 6 * a0 - 2200)

# %%
MSEa2
# Out:
# 4.0*a0 + 1666.66666666667*a1 + 9.33333333333333*a2 - 1666.66666666667

# %%
MSEa1
# Out:
# 800.0*a0 + 363333.333333333*a1 + 1666.66666666667*a2 - 336666.666666667

# %%
MSEa0
# Out:
# 2.0*a0 + 800.0*a1 + 4.0*a2 - 733.333333333333

# %%
nonlinsolve([MSEa2, MSEa1, MSEa0], [a2, a1, a0])
# Out:
# FiniteSet((108.333333333333, 0.833333333333333, -183.333333333334))

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)**2 + 0.333333333333333*(a0 + 450*a1 + a2 - 300)**2 + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)**2

# %%
MSE.subs({a2: 108.333333333333, a1: 0.833333333333333, a0: -183.333333333334})
# Out:
# 28009.2592592593

# %% [markdown]
# ![image.png](attachment:7b112b55-71bf-4e60-8278-4e188701178d.png)

# %%
x2, x1 = symbols('x2, x1')

# %%
f = 325 / 3 * x2 + 2.5 / 3 * x1 - 550 / 3 
f
# Out:
# 0.833333333333333*x1 + 108.333333333333*x2 - 183.333333333333

# %%
f.subs({'x1': 500, 'x2': 4})
# Out:
# 666.666666666667

# %% [markdown]
# ![image.png](attachment:03ae9e09-7735-42a7-b71a-6ccb5befcadd.png)

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)**2 + 0.333333333333333*(a0 + 450*a1 + a2 - 300)**2 + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)**2

# %%
MSEa2 = 1/3 * (28 * a2 + 5000 * a1 + 12 * a0 - 5000)
MSEa1 = 1/3 * (5000 * a2 + 1090000 * a1 + 2400 * a0 - 1010000)
MSEa0 = 1/3 * (12 * a2 + 2400 * a1 + 6 * a0 - 2200)

# %%
diff(MSE, a2)
# Out:
# 4.0*a0 + 1666.66666666667*a1 + 9.33333333333333*a2 - 1666.66666666667

# %%
MSEa2
# Out:
# 4.0*a0 + 1666.66666666667*a1 + 9.33333333333333*a2 - 1666.66666666667

# %%
diff(MSE, a1)
# Out:
# 800.0*a0 + 363333.333333333*a1 + 1666.66666666667*a2 - 336666.666666667

# %%
MSEa1
# Out:
# 800.0*a0 + 363333.333333333*a1 + 1666.66666666667*a2 - 336666.666666667

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)**2 + 0.333333333333333*(a0 + 450*a1 + a2 - 300)**2 + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)**2

# %%
a2, a1, a0 = symbols('a2 a1 a0')

# %%
MSE2 = diff(MSE, a2)
MSE2
# Out:
# 4.0*a0 + 1666.66666666667*a1 + 9.33333333333333*a2 - 1666.66666666667

# %%
# Практика

# %% [markdown]
# ![image.png](attachment:da11fc1f-829d-47c7-85cb-2c7e65a8d1b1.png)

# %%
# x1, x2, y

# %%
MSE = 1/3 * (
    ((a2 * 2 + a1 * 200 + a0) - 200)**2 +
    ((a2 * 1 + a1 * 300 + a0) - 450)**2 +
    ((a2 * 3 + a1 * 600 + a0) - 550)**2
)
MSE
# Out:
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)**2 + 0.333333333333333*(a0 + 300*a1 + a2 - 450)**2 + 0.333333333333333*(a0 + 600*a1 + 3*a2 - 550)**2

# %%
MSE2 = diff(MSE, a2)
print(MSE2)
MSE1 = diff(MSE, a1)
print(MSE1)
MSE0 = diff(MSE, a0)
print(MSE0)
# Out:
# 4.0*a0 + 1666.66666666667*a1 + 9.33333333333333*a2 - 1666.66666666667
# 733.333333333333*a0 + 326666.666666667*a1 + 1666.66666666667*a2 - 336666.666666667
# 2.0*a0 + 733.333333333333*a1 + 4.0*a2 - 800.0

# %%
nonlinsolve([MSE2, MSE1, MSE0], [a2, a1, a0])
# Out:
# FiniteSet((-130.0, 1.2, 220.0))

# %%
MSE.subs({a2: -130.0, a1: 1.2, a0: 220.0})
# Out:
# 3.88842687865190e-27

# %%
x2, x1 = symbols('x2, x1')

# %%
f = -130.0 * x2 + 1.2 * x1 + 220.0
f
# Out:
# 1.2*x1 - 130.0*x2 + 220.0

# %%
f.subs({'x1': 666, 'x2': 4})
# Out:
# 499.200000000000
