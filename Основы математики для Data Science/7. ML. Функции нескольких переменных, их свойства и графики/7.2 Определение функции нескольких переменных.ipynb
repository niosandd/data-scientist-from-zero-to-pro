# %% [markdown]
# ![image.png](attachment:fe034add-aea6-4a94-816c-50b05e296f58.png)

# %% [markdown]
# ![image.png](attachment:0e2de4dd-23cd-44e2-9b0b-454d00804cba.png)

# %% [markdown]
# ![image.png](attachment:e5126e41-0088-404f-8877-33a82cadf794.png)

# %% [markdown]
# ![image.png](attachment:417df541-e14e-4c3f-92ec-a0099377043c.png)

# %% [markdown]
# ![image.png](attachment:433496c2-eb45-4745-949c-2035ce126677.png)

# %% [markdown]
# ![image.png](attachment:3911c3aa-c48c-422f-8e03-4b6c54dcdd1a.png)

# %% [markdown]
# ![image.png](attachment:49eddb37-bab1-4375-932e-a77cde75eb7d.png)

# %% [markdown]
# ![image.png](attachment:e7deced0-c50a-4020-908a-36b5c6d25a1f.png)
