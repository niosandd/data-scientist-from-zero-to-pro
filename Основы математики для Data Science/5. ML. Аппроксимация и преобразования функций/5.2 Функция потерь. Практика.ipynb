# %%
import math

# %% [markdown]
# ![image.png](attachment:dce8fd3d-9123-4464-a90d-660fade46aac.png)

# %%
MSE = ((12.258 - (3*2+5))**2 + (17.24 - (4*3+5)) ** 2 + (30.151 - (8 * 3 + 5)) ** 2) / 3
print('MSE:', MSE)
RMSE = math.sqrt(MSE)
print("RMSE:", RMSE)
# Out:
# MSE: 0.9883216666666655
# RMSE: 0.9941436851213539

# %% [markdown]
# ![image.png](attachment:bc2af85f-7f8f-443c-a174-6f6520995f5e.png)

# %%
MSE = ((3.688 - (0.25 * 2 ** 2 + 0.75 * 2 + 1.25)) ** 2 + (10.791 - (0.25 * 4 ** 2 + 0.75 * 4 + 1.25)) ** 2 + (20.705 - (0.25 * 8 ** 2 + 0.75 * 8 + 1.25)) ** 2) / 3
print('MSE:', MSE)
RMSE = math.sqrt(MSE)
print("RMSE:", RMSE)
# Out:
# MSE: 4.31251666666667
# RMSE: 2.076659978587412

# %% [markdown]
# ![image.png](attachment:4dd7343d-7b29-4dca-9740-ee0398f04b65.png)

# %%
MSE = (
    (4.872  - (0.5 * 2**3  - 0.25 * 2**2  + 0.75 * 2  + 1.25))**2 +
    (29.707 - (0.5 * 4**3  - 0.25 * 4**2  + 0.75 * 4  + 1.25))**2 +
    (246.971- (0.5 * 8**3  - 0.25 * 8**2  + 0.75 * 8  + 1.25))**2 +
    (485.727- (0.5 * 10**3 - 0.25 * 10**2 + 0.75 * 10 + 1.25))**2 +
    (840.658- (0.5 * 12**3 - 0.25 * 12**2 + 0.75 * 12 + 1.25))**2
) / 5

# %%
print('MSE:', MSE)
RMSE = math.sqrt(MSE)
print("RMSE:", RMSE)
# Out:
# MSE: 3.404513399999994
# RMSE: 1.845132352976337
