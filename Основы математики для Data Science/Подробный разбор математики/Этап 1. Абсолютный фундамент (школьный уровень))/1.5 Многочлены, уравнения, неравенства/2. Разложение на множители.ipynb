# %% [markdown]
# # **Разложение на множители**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# ![image.png](attachment:69589cd9-c313-4481-b2b7-b0244c1d8c56.png)

# %% [markdown]
# # **1. Разложение многочлена на множители**

# %% [markdown]
# ![image.png](attachment:3bc054cd-d9b4-4c33-aa81-af92a1fecf83.png)

# %% [markdown]
# ![image.png](attachment:6d3319ab-16ba-4972-bc41-742977cedb42.png)

# %% [markdown]
# ![image.png](attachment:9a506c4a-1a2c-4d23-9dbc-891ed8740d2b.png)

# %% [markdown]
# ![image.png](attachment:88a26711-9df2-4841-9469-5590e191a318.png)

# %% [markdown]
# ![image.png](attachment:80c337e5-254b-4d22-bab8-3ba5000bc3d8.png)

# %% [markdown]
# ![image.png](attachment:93248b45-45a1-4fb5-a8d1-5f77d65ef462.png)

# %% [markdown]
# ![image.png](attachment:1e0e4778-aa7f-4839-b344-13fb60112a04.png)

# %% [markdown]
# ![image.png](attachment:ed0cf986-3eff-47ec-914b-3deb0f44461d.png)

# %% [markdown]
# ![image.png](attachment:2a2d72b8-5fa3-4d34-a858-035353d6ed78.png)

# %% [markdown]
# ![image.png](attachment:9ffdddde-cc3e-4108-941e-e46774979bb0.png)

# %% [markdown]
# ![image.png](attachment:8aed63cd-ab55-4e9d-90e2-6487cd39a688.png)

# %% [markdown]
# # **2. Разложение на множители в уравнениях. Тождества**

# %% [markdown]
# ![image.png](attachment:8d577179-1393-4e0d-a4fe-496f967734d4.png)

# %% [markdown]
# ![image.png](attachment:c7209827-172f-45b7-8755-b5e68419f47e.png)

# %% [markdown]
# ![image.png](attachment:b18746c2-b6fe-423d-a9ad-9e3cfe5daa65.png)

# %% [markdown]
# ![image.png](attachment:cb26e8fd-29e6-4695-a8ef-334dd876ea3b.png)

# %% [markdown]
# ![image.png](attachment:c778c575-6c4e-40d7-9206-79b8f1046012.png)

# %% [markdown]
# # **3. Формулы сокращённого умножения: квадраты**

# %% [markdown]
# ![image.png](attachment:d72c7aa9-81c2-4276-89bf-682ee0213b6f.png)

# %% [markdown]
# ![image.png](attachment:04f1f39e-d379-4d05-8238-56c87df5d810.png)

# %% [markdown]
# ![image.png](attachment:f7557ac3-5693-4e77-ae24-531120dfb0f9.png)

# %% [markdown]
# ![image.png](attachment:f75500e3-51e2-4e7c-a198-d79879eb37ca.png)

# %% [markdown]
# ![image.png](attachment:94f014cf-345d-4970-889e-44b92a6179d1.png)

# %% [markdown]
# ![image.png](attachment:b56896b5-bd96-4aaa-b3f9-4aa76e2c173a.png)

# %% [markdown]
# # **4. Формулы сокращённого умножения: кубы**

# %% [markdown]
# ![image.png](attachment:bbc8dd33-0c20-4ec2-a746-293b3290cb6d.png)

# %% [markdown]
# ![image.png](attachment:b267df26-f6e8-43b5-81b9-5680f22b742c.png)

# %% [markdown]
# ![image.png](attachment:a74627b8-4638-4cf8-a657-de76a4fe7505.png)

# %% [markdown]
# ![image.png](attachment:43041673-1d7d-43b5-a425-a5e8079c1ebd.png)

# %% [markdown]
# ![image.png](attachment:94143424-5ff5-478d-b89b-5557b0db2670.png)

# %% [markdown]
# ![image.png](attachment:c5d744f7-a19e-4433-ae9e-c0b832804743.png)

# %% [markdown]
# ![image.png](attachment:174c37f6-4978-45e8-bab5-f2b45fba2a55.png)

# %% [markdown]
# # **5. Квадратный корень**

# %% [markdown]
# ![image.png](attachment:d3f2ee84-2051-42fd-98a9-9d2a0490615c.png)

# %% [markdown]
# ![image.png](attachment:c7c9a9b2-60eb-49cc-8e14-b58016ed70a8.png)

# %% [markdown]
# ![image.png](attachment:c29801ae-e94c-4475-a677-3f1c53e94c82.png)

# %% [markdown]
# ![image.png](attachment:5feb8d4d-775c-4861-b3a1-f6f1de77e739.png)

# %% [markdown]
# ![image.png](attachment:5d64ed78-1355-4b39-baa5-e765509addb1.png)

# %% [markdown]
# ![image.png](attachment:d76c33af-6b11-41c3-b55a-b381d5659eb2.png)

# %% [markdown]
# ![image.png](attachment:ce8449c5-0a7e-431d-bacc-bcfcc3647e19.png)

# %% [markdown]
# ![image.png](attachment:a693e081-494d-4aed-8d76-2f1f12d1da53.png)

# %% [markdown]
# ![image.png](attachment:825de5bf-0470-4c3d-916d-51863a84f037.png)

# %% [markdown]
# ![image.png](attachment:bb7d6f27-0865-48ae-a08e-ac63925fdabe.png)

# %% [markdown]
# ![image.png](attachment:f62b7b7e-b59b-47a9-81bc-038c5356deba.png)

# %% [markdown]
# # **6. Неполные квадратные уравнения. Теорема Виета**

# %% [markdown]
# ![image.png](attachment:bfc42969-6241-488d-b668-c4346d08195c.png)

# %% [markdown]
# ![image.png](attachment:4dba4740-ccce-400e-b5cb-2e145335fd01.png)

# %% [markdown]
# ![image.png](attachment:1d482748-5c99-4cad-940b-eef925c35fc8.png)

# %% [markdown]
# ![image.png](attachment:4422fde5-7fc8-4fae-a950-b301f48284ac.png)

# %% [markdown]
# ![image.png](attachment:a1d18e4d-c36e-42bf-b569-ca169da44e72.png)

# %% [markdown]
# ![image.png](attachment:626ac7d8-28e1-4ef3-a2f2-3f564b97eaa6.png)

# %% [markdown]
# ![image.png](attachment:65f57a91-b07a-4a0c-baf7-595c55008ca7.png)

# %% [markdown]
# ![image.png](attachment:92fcecc7-3aa9-4cf8-b41d-1d1029e0dab2.png)

# %% [markdown]
# ![image.png](attachment:aa60c6d0-fba4-4a2f-b1b4-8f9e4ed25e58.png)

# %% [markdown]
# ![image.png](attachment:904b52ba-f45d-4d73-8854-f8984c4fca17.png)

# %% [markdown]
# ![image.png](attachment:ee5fc58a-d1c1-4e22-9d32-719e3e7dbe4e.png)

# %% [markdown]
# # **7. Дискриминант, разложение на множители**

# %% [markdown]
# ![image.png](attachment:59ad4c65-062f-4538-86af-0ea03d8eaacb.png)

# %% [markdown]
# ![image.png](attachment:54216469-dd5c-4634-80e3-daf8d36cfb59.png)

# %% [markdown]
# ![image.png](attachment:bf2e75c7-a67b-48ad-b75e-f9399fccabdb.png)

# %% [markdown]
# ![image.png](attachment:06a7293d-c092-43c0-9845-81ac1938b536.png)

# %% [markdown]
# ![image.png](attachment:76a83696-72f9-4985-84c2-a543b77f1c3f.png)

# %% [markdown]
# ![image.png](attachment:c01f6815-9e59-4b29-b654-22bbe2669c40.png)

# %% [markdown]
# ![image.png](attachment:fe915ca3-4b93-4a3a-8ec2-f802444a43af.png)

# %% [markdown]
# ![image.png](attachment:85968b32-89f9-4a6f-8a72-b8d3b75d9413.png)

# %% [markdown]
# ![image.png](attachment:b72d81ea-659d-4e3d-99f1-f6cb51ec3c50.png)

# %% [markdown]
# ![image.png](attachment:41ebf4c2-f941-4a77-9699-53d2b0574376.png)

# %% [markdown]
# ![image.png](attachment:4d2c7100-df23-4ee6-a10d-583449a068ee.png)

# %% [markdown]
# ![image.png](attachment:d023b30d-fde5-4f49-a158-6a251916d158.png)

# %% [markdown]
# # **8. Текстовые задачи и дробно-рациональные уравнения**

# %% [markdown]
# ![image.png](attachment:372300ed-c87c-41bb-a3b8-fa06624d9200.png)

# %% [markdown]
# ![image.png](attachment:be280a6b-1ae2-4824-bb8e-7491e7665840.png)

# %% [markdown]
# ![image.png](attachment:60284c16-2bbc-4103-bdbc-e38e8b9ce832.png)

# %% [markdown]
# ![image.png](attachment:8e4313e7-991c-4b40-9ba3-e9d9bb72a00e.png)

# %% [markdown]
# ![image.png](attachment:e83ac78e-74ca-4387-a016-ac5921c0a14e.png)

# %% [markdown]
# ![image.png](attachment:e8811f19-fe6d-4a40-a47d-64ed4e32614d.png)

# %% [markdown]
# ![image.png](attachment:cfbb2c05-925e-4761-bfb3-b8c86ab7d22f.png)

# %% [markdown]
# ![image.png](attachment:3f867d7a-4176-47e6-95aa-0f096a10dc23.png)

# %% [markdown]
# ![image.png](attachment:16c322ef-bc2d-403e-8a70-a3e160d61387.png)

# %% [markdown]
# ![image.png](attachment:ae21568a-ac72-4003-9436-e498cead9947.png)

# %% [markdown]
# ![image.png](attachment:97c0772c-218a-4441-95af-31ba567c1844.png)

# %% [markdown]
# ![image.png](attachment:1f425092-0582-4ea4-8863-36ed690d3a7d.png)

# %% [markdown]
# ![image.png](attachment:e8723b17-db60-440c-8338-871f7b9fd87e.png)

# %% [markdown]
# ![image.png](attachment:264ccc09-566e-4175-bd77-45067f17810f.png)

# %% [markdown]
# ![image.png](attachment:26dca07d-2b52-4331-9c0f-98a3e834c3fd.png)
