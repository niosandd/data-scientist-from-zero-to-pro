# %% [markdown]
# # **Неравенства**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# ![image.png](attachment:f57a16a3-6c5c-4978-bc11-6f94335c0578.png)

# %% [markdown]
# # **1. Неравенства и их свойства. Виды промежутков**

# %% [markdown]
# ![image.png](attachment:8f6f1756-3553-491b-9fc1-3c4b83d9cd2a.png)

# %% [markdown]
# ![image.png](attachment:c89ec5b9-1fde-4e90-a460-db05f43488d7.png)

# %% [markdown]
# ![image.png](attachment:195ae2ef-00bb-4219-a716-0b28464b8ab8.png)

# %% [markdown]
# ![image.png](attachment:1f470b08-ce11-41c9-af81-035484ce2f8f.png)

# %% [markdown]
# ![image.png](attachment:ac9f5576-0100-453b-9e92-ffb4a97b5a3b.png)

# %% [markdown]
# ![image.png](attachment:fcc4f9a8-aad2-4c28-a05f-98d614bf3f11.png)

# %% [markdown]
# ![image.png](attachment:02a1528e-9262-4fdf-9e81-c9126187f447.png)

# %% [markdown]
# ![image.png](attachment:2c442bed-49a8-42e5-9509-82adfd71d2ee.png)

# %% [markdown]
# ![image.png](attachment:72ed008b-e403-4abd-baee-8fce2d3b7d75.png)

# %% [markdown]
# ![image.png](attachment:9195cd5f-8fb1-4a18-85b4-3a68aeeca8bd.png)

# %% [markdown]
# ![image.png](attachment:98e205b6-a8ec-4fbc-a04d-7113891dfb43.png)

# %% [markdown]
# ![image.png](attachment:ae08532f-ef8e-4b39-8cb6-5148001a4c16.png)

# %% [markdown]
# ![image.png](attachment:98eab968-afc2-4aa1-9dc6-f98eaa8e0825.png)

# %% [markdown]
# ![image.png](attachment:84366c8f-331d-4ce4-9b31-c732eca53c24.png)

# %% [markdown]
# # **2. Линейные неравенства и системы с ними**

# %% [markdown]
# ![image.png](attachment:3af8dc0f-e44d-4501-8266-5a24c606e604.png)

# %% [markdown]
# ![image.png](attachment:9d843ad0-e50b-4c50-908f-6b201b4fe38a.png)

# %% [markdown]
# ![image.png](attachment:c4911cb5-d4fd-475b-b25c-4bb730403b3a.png)

# %% [markdown]
# ![image.png](attachment:6406d533-b17e-404d-85c6-fdb016f380bf.png)

# %% [markdown]
# ![image.png](attachment:eb783156-6362-4158-a993-ab8cbf3edc90.png)

# %% [markdown]
# ![image.png](attachment:b085aa6d-d823-4322-9ae2-2f2920c3df79.png)

# %% [markdown]
# ![image.png](attachment:fd9479da-2d9b-45bb-be5b-b4e16b1a2ac1.png)

# %% [markdown]
# ![image.png](attachment:39c17217-bcc5-4730-9730-666faf22d113.png)

# %% [markdown]
# ![image.png](attachment:7356f826-9b03-462d-83b0-0d3b694bae9d.png)

# %% [markdown]
# ![image.png](attachment:896c3bf9-f04f-4c28-93db-ae93d9255324.png)

# %% [markdown]
# ![image.png](attachment:d847de86-3376-4439-8875-e83cf1fbb4f0.png)

# %% [markdown]
# ![image.png](attachment:4729a24a-fb22-46e9-a0c3-2039a209265d.png)

# %% [markdown]
# ![image.png](attachment:6fb0b063-4b36-47c6-bb52-a2dee179c62d.png)

# %% [markdown]
# ![image.png](attachment:413f9684-bc62-42b1-a74d-7a01a8b61fc6.png)

# %% [markdown]
# ![image.png](attachment:a1d43c92-8b22-4f27-b78d-e96d37276ec4.png)

# %% [markdown]
# ![image.png](attachment:9323bcf8-ebfa-4dc0-ad61-64bea1f53798.png)

# %% [markdown]
# ![image.png](attachment:f3ebb144-819a-45ed-816f-be7683273fb4.png)

# %% [markdown]
# # **3. Метод интервалов**

# %% [markdown]
# ![image.png](attachment:8bbe0076-b353-4668-be58-0d28b8d2b670.png)

# %% [markdown]
# ![image.png](attachment:4eb5af80-bba6-4ae3-91b9-54b6c23785aa.png)

# %% [markdown]
# ![image.png](attachment:daffc699-9cf4-41c0-91fb-67fcb56f7d79.png)

# %% [markdown]
# ![image.png](attachment:b929f738-12f9-4ed8-be7c-ec15e38b3877.png)

# %% [markdown]
# ![image.png](attachment:761d0850-7a7c-4614-ad64-227473fbc322.png)

# %% [markdown]
# ![image.png](attachment:67439757-5017-4716-98e4-e610c45782b6.png)

# %% [markdown]
# ![image.png](attachment:6f61b2ab-311b-470b-9b4f-9c3e3cd5c06b.png)

# %% [markdown]
# ![image.png](attachment:e1649bd5-a04a-47f9-b3e3-9840104e7189.png)

# %% [markdown]
# ![image.png](attachment:533ed2b7-7852-4967-a6f7-cec9ff2b411c.png)

# %% [markdown]
# ![image.png](attachment:f41828c7-b079-4b86-a40f-42d339b43514.png)

# %% [markdown]
# ![image.png](attachment:d63498d5-19e0-43c7-b3b0-13e1886f0bdf.png)

# %% [markdown]
# ![image.png](attachment:8de5e872-1d1e-4022-83ba-e6f69248ce50.png)

# %% [markdown]
# ![image.png](attachment:bb4aa2fe-53d7-4979-87e1-21ba55e5d6f4.png)

# %% [markdown]
# ![image.png](attachment:97179798-1ca5-42f6-8df3-ae9003a88de7.png)

# %% [markdown]
# # **4. Дробно-рациональные неравенства**

# %% [markdown]
# ![image.png](attachment:18570289-c793-455e-8bca-6de222595b1e.png)

# %% [markdown]
# ![image.png](attachment:0b1bb15b-8819-4c38-ae6f-900a087e3549.png)

# %% [markdown]
# ![image.png](attachment:2ca8599e-ae13-4906-bf40-0b9cbc5bb142.png)

# %% [markdown]
# ![image.png](attachment:d0564f7f-4022-4aab-9235-3dadbfb3e64f.png)

# %% [markdown]
# ![image.png](attachment:b05e9272-b407-422c-b95b-032f47446bd7.png)

# %% [markdown]
# ![image.png](attachment:198a1cdb-db14-4abd-a4ba-f8381f73ec10.png)

# %% [markdown]
# ![image.png](attachment:e3a5274a-b8bb-4aea-8e09-49ae52ae57fd.png)

# %% [markdown]
# ![image.png](attachment:b986a176-bd28-4a94-8a56-7e3433b11834.png)

# %% [markdown]
# ![image.png](attachment:9aa8c25e-e89d-4637-9c00-685aa6695b2c.png)

# %% [markdown]
# ![image.png](attachment:181a6cc2-d4c8-4f9d-9b43-b0fa5bafd7f1.png)

# %% [markdown]
# ![image.png](attachment:a6c3cd2c-fef0-4aa6-8ac1-e3ae35a17952.png)

# %% [markdown]
# ![image.png](attachment:180f762c-0876-4b4f-8d97-6abb663e2a4e.png)

# %% [markdown]
# ![image.png](attachment:70b4400e-277d-4923-9c18-0b6cf2192b4e.png)

# %% [markdown]
# ![image.png](attachment:b14236a5-1ae8-47a8-aa37-2c125f437c08.png)

# %% [markdown]
# ![image.png](attachment:d9731a50-7e90-421f-968f-217a0beb6509.png)

# %% [markdown]
# ![image.png](attachment:07f85b46-a5a1-4452-b972-66598361244f.png)

# %% [markdown]
# ![image.png](attachment:5f7a487b-a9cb-40a8-b58f-d8cbcdbced49.png)
