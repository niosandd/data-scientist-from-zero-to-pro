# %% [markdown]
# # **Переменные, выражения. Одночлен, многочлен**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# ![image.png](attachment:0ae2a8f5-c1b7-441e-af1f-58232dd4eb66.png)

# %% [markdown]
# # **1. Переменные, выражения. Одночлен, многочлен**

# %% [markdown]
# ![image.png](attachment:e40d7600-6952-40c5-84ce-8f907390a6ce.png)

# %% [markdown]
# ![image.png](attachment:0c4ced5a-562f-4bce-944d-66891d549b56.png)

# %% [markdown]
# ![image.png](attachment:0bb49a74-3b41-408f-aa5f-b8341001b86c.png)

# %% [markdown]
# ![image.png](attachment:aafe262a-e7aa-47f5-9e01-b86ff3f40e9f.png)

# %% [markdown]
# ![image.png](attachment:1df55945-51f5-4846-baba-0ac842f7d624.png)

# %% [markdown]
# ![image.png](attachment:ac2c3eaf-f459-498c-ab02-a304bcbc41c6.png)

# %% [markdown]
# ![image.png](attachment:243af304-986c-4428-bc58-3b7789a5699c.png)

# %% [markdown]
# ![image.png](attachment:7160712c-4c2d-4baf-99d9-fa93e2e362e2.png)

# %% [markdown]
# ![image.png](attachment:5370cc45-168a-4e6f-96a5-8abc50eb7541.png)

# %% [markdown]
# # **2. Подобные слагаемые и стандартный вид**

# %% [markdown]
# ![image.png](attachment:7598efc3-47e9-4d11-a504-84d78e24d279.png)

# %% [markdown]
# ![image.png](attachment:49021665-934a-4508-a4ff-0535f9e606b5.png)

# %% [markdown]
# ![image.png](attachment:41c3e61f-bbc0-4ec7-a725-1c56fa99748f.png)

# %% [markdown]
# ![image.png](attachment:0fe6aec5-54df-4fb8-90e8-2801c550ccf0.png)

# %% [markdown]
# ![image.png](attachment:1bc4efb3-0cff-4b0a-97cb-c9c333b9d848.png)

# %% [markdown]
# ![image.png](attachment:635f3897-ba12-4e1e-a530-43bd1f630186.png)

# %% [markdown]
# ![image.png](attachment:93619757-bdfb-4805-860c-55a6ea4ea9f7.png)

# %% [markdown]
# ![image.png](attachment:87e12e21-e58f-494f-88b5-f626199e9346.png)

# %% [markdown]
# ![image.png](attachment:213a82ed-56b8-4adb-8f5a-7a3e9bca74b4.png)

# %% [markdown]
# ![image.png](attachment:b38d4e35-f885-41a2-99f7-fa6c2d3acbe0.png)

# %% [markdown]
# ![image.png](attachment:6f388bee-0211-4bca-ba4f-1dd216211556.png)

# %% [markdown]
# ![image.png](attachment:6eaca71a-ec66-4e44-bfde-3b558ba63ef1.png)

# %% [markdown]
# ![image.png](attachment:27dd72aa-2ee9-4ec6-8a2d-799137304467.png)

# %% [markdown]
# # **3. Раскрытие скобок. Уравнения и их корни**

# %% [markdown]
# ![image.png](attachment:947631f2-0b2e-4315-b640-9b4c6dc82609.png)

# %% [markdown]
# ![image.png](attachment:198f8ee3-3d02-4a91-ac8e-eed37aa00930.png)

# %% [markdown]
# ![image.png](attachment:3079cbbc-3371-40aa-b7cf-0741acd572a4.png)

# %% [markdown]
# ![image.png](attachment:26ef6da4-9e77-4b2c-a833-c0002cc00317.png)

# %% [markdown]
# ![image.png](attachment:d5ed171a-e63f-4c8e-9d86-927a7ef1e4c9.png)

# %% [markdown]
# ![image.png](attachment:e6b7eb1a-e599-4d43-bce0-e1f5ed23581d.png)

# %% [markdown]
# ![image.png](attachment:1cbb3a8e-753f-4978-9084-8b9407299ec0.png)

# %% [markdown]
# ![image.png](attachment:e4c74819-e7e8-4187-87c1-ff00b60a437d.png)

# %% [markdown]
# ![image.png](attachment:f44d8dc2-f63c-4c94-a7f6-ab39239dd343.png)

# %% [markdown]
# ![image.png](attachment:ebf1b2cd-c9c7-4f1e-9d33-1506e33e8247.png)

# %% [markdown]
# # **4. Линейные уравнения и задачи на них**

# %% [markdown]
# ![image.png](attachment:c383dffe-8669-4ef9-b56c-9dbebea07566.png)

# %% [markdown]
# ![image.png](attachment:a46ca007-a3a7-43be-bd81-912d09d4d1a3.png)

# %% [markdown]
# ![image.png](attachment:502513f2-6b80-4829-a699-c1818d624961.png)

# %% [markdown]
# ![image.png](attachment:241209cb-7e37-45d0-bc52-bc44203bc111.png)

# %% [markdown]
# ![image.png](attachment:52aa3fbe-bce2-4ab6-a52f-beea818c8518.png)

# %% [markdown]
# ![image.png](attachment:f8658e92-a7ca-4630-8366-5ba372708fa9.png)

# %% [markdown]
# ![image.png](attachment:71b82174-f8ce-458b-a2c8-5851c7c702b8.png)

# %% [markdown]
# ![image.png](attachment:f31c5720-11b8-4593-b8c7-a53cb7046fb1.png)

# %% [markdown]
# ![image.png](attachment:a2bf5b62-cb92-4f1e-8062-2c1fea901e74.png)

# %% [markdown]
# ![image.png](attachment:46e9f4c8-9d76-423c-85d4-7f2cbe48efc3.png)

# %% [markdown]
# ![image.png](attachment:a31cbb0a-73ae-49c7-87ec-fa9b9f0ff071.png)

# %% [markdown]
# # **5. Уравнения и системы уравнений в целых числах**

# %% [markdown]
# ![image.png](attachment:cbbed19d-af1e-40a8-85aa-a4f839532fac.png)

# %% [markdown]
# ![image.png](attachment:5153522e-1377-48ee-baa1-e18b34b1d838.png)

# %% [markdown]
# ![image.png](attachment:b03643be-895d-413d-b6bd-a4ea804e3f15.png)

# %% [markdown]
# ![image.png](attachment:30b24bec-5c3e-4f8f-836e-e195c754216f.png)

# %% [markdown]
# ![image.png](attachment:cfae9404-4817-46a0-9343-e1056c6f2f80.png)

# %% [markdown]
# ![image.png](attachment:a916731f-65d5-4e22-8be3-0e27eed3fec8.png)

# %% [markdown]
# ![image.png](attachment:f2893ec8-5689-4a7e-adec-5aa3219da749.png)

# %% [markdown]
# ![image.png](attachment:3a54b35c-b7a9-4c29-b3a1-05cf89b7759d.png)

# %% [markdown]
# ![image.png](attachment:1b14fc36-fc5f-4d5f-8d54-09c8a2418afa.png)

# %% [markdown]
# ![image.png](attachment:59484302-c1ca-4ee2-b06d-e85bd10c7c2a.png)

# %% [markdown]
# ![image.png](attachment:0b50ec3f-3811-4dfb-8235-0ce944316ce2.png)

# %% [markdown]
# # **6. Системы линейных уравнений**

# %% [markdown]
# ![image.png](attachment:6a9847cd-c547-483a-87ee-e46751a5b22a.png)

# %% [markdown]
# ![image.png](attachment:7eeede88-0cac-41b0-896c-faf1d83f60a3.png)

# %% [markdown]
# ![image.png](attachment:a477c78d-b847-4b92-96a4-c89dc7fd34c1.png)

# %% [markdown]
# ![image.png](attachment:efc0d5e7-c69c-442d-b554-4c605253c98d.png)

# %% [markdown]
# ![image.png](attachment:6bb97b40-ca22-42e1-acd0-dd50ed8c2686.png)

# %% [markdown]
# ![image.png](attachment:f4ca1fec-103f-4521-9223-2529b14eb316.png)

# %% [markdown]
# ![image.png](attachment:56da62e2-a65b-4187-a02b-b3dd3fe618ab.png)

# %% [markdown]
# ![image.png](attachment:4de7030f-43c2-4ab4-9bac-a296a23509a3.png)

# %% [markdown]
# ![image.png](attachment:7a4928eb-097a-4fda-833e-dc6d6bfb8d84.png)

# %% [markdown]
# ![image.png](attachment:317b1570-7f8e-4796-8c4f-f866f2164681.png)

# %% [markdown]
# ![image.png](attachment:265a9c94-8c29-4b46-a695-12e6e17dc8a4.png)

# %% [markdown]
# ![image.png](attachment:107f6d15-b190-414a-a208-57c988113649.png)

# %% [markdown]
# ![image.png](attachment:b0cd2066-ed92-4820-a43b-e75d7d88955c.png)

# %% [markdown]
# ![image.png](attachment:a0d91033-9126-4f98-a047-5c9f525016a6.png)

# %% [markdown]
# ![image.png](attachment:83c4f9a2-b347-49ec-8e5f-118e63fefe51.png)

# %% [markdown]
# ![image.png](attachment:8b23a48b-bd5e-4d06-9d0e-8e73562ae1d4.png)

# %% [markdown]
# ![image.png](attachment:f37b5e5e-d4d6-4568-a802-707655693b29.png)
