# %% [markdown]
# # **Проценты**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Понятие процента**

# %% [markdown]
# ![image.png](attachment:6a6f60dd-d788-4f38-9110-5ccaf3e4c1b5.png)

# %% [markdown]
# ![image.png](attachment:46df86c6-846c-41cf-bf48-cf8b3ea1db12.png)

# %% [markdown]
# ![image.png](attachment:9953ba98-cc94-477d-b8b1-1c77cc39de86.png)

# %% [markdown]
# ![image.png](attachment:e3dab6c1-e554-4232-8c5d-5bca6dbdf5cb.png)

# %% [markdown]
# ![image.png](attachment:bfe8edad-d86a-400f-b3f9-dc3f895497d9.png)

# %% [markdown]
# ![image.png](attachment:274e653f-fd28-45a6-8094-d6c679cb2f9f.png)

# %% [markdown]
# ![image.png](attachment:f00b33a4-76a1-4a8f-a8fc-ae5dca53daea.png)

# %% [markdown]
# ![image.png](attachment:c7a4df41-b9c6-4d0d-bfc7-1410a5ba7ac5.png)

# %% [markdown]
# ![image.png](attachment:d5c2ab5c-5635-42db-a437-15374419c3b3.png)

# %% [markdown]
# ![image.png](attachment:d60b9cd3-fd7b-43ae-9f5e-3a44d5ae3006.png)

# %% [markdown]
# ![image.png](attachment:29ed0a13-f6c0-4fe1-967e-8929690b293f.png)

# %% [markdown]
# ![image.png](attachment:1cb35215-07aa-452c-b184-c4516e047530.png)

# %% [markdown]
# ![image.png](attachment:3cb8601a-594f-4654-be02-88441adcb59f.png)

# %% [markdown]
# ![image.png](attachment:232f7e7a-8ae2-4bfa-8ed5-e284391ed4c1.png)

# %% [markdown]
# ![image.png](attachment:9be2d568-be25-4977-80c8-c2344adca1a8.png)

# %% [markdown]
# ![image.png](attachment:e40a748f-30c4-4650-bdf8-88c7f6ee84ac.png)

# %% [markdown]
# # **2. Процент от числа и число по проценту**

# %% [markdown]
# ![image.png](attachment:40b41f01-296e-4791-80f9-46f4c97e6b34.png)

# %% [markdown]
# ![image.png](attachment:30b8504f-a477-4601-9ed2-506ba47671d4.png)

# %% [markdown]
# ![image.png](attachment:bc8a5670-e29c-4bbe-a45b-9a5c03f5c0b5.png)

# %% [markdown]
# ![image.png](attachment:43b1d9db-1655-4f74-bd08-bb48a13e3ffa.png)

# %% [markdown]
# ![image.png](attachment:b8726cc2-b0c9-4139-8325-eac61f952d9b.png)

# %% [markdown]
# ![image.png](attachment:72651050-ff19-4fc3-95e3-0ba54504eb95.png)

# %% [markdown]
# ![image.png](attachment:994fb62e-2135-4c08-895c-a298fef684ab.png)

# %% [markdown]
# ![image.png](attachment:c987840e-fc52-4843-b4cd-80a83be6a203.png)

# %% [markdown]
# ![image.png](attachment:2a3b8bef-d05f-4f38-8c61-2e713a0e9958.png)

# %% [markdown]
# ![image.png](attachment:daa0545b-c049-47a0-bd19-ab20086c1522.png)

# %% [markdown]
# ![image.png](attachment:75b723ac-4826-40ff-8b19-a44488e40a32.png)

# %% [markdown]
# # **3. Задачи на изменение процентов**

# %% [markdown]
# ![image.png](attachment:7ad87160-fd30-4d13-9a1c-9a8b31095425.png)

# %% [markdown]
# ![image.png](attachment:4a7ae726-d4b5-4ad3-85ec-f98018582091.png)

# %% [markdown]
# ![image.png](attachment:3025f189-fa91-40e0-acf9-0c36e0a10697.png)

# %% [markdown]
# ![image.png](attachment:45000b23-ed73-4b74-951e-203c1e83cc2c.png)

# %% [markdown]
# ![image.png](attachment:3016f793-ddce-4316-84ea-6a63fb20652d.png)

# %% [markdown]
# ![image.png](attachment:c3df3d52-5f36-42db-b56b-6069c15fbbd1.png)

# %% [markdown]
# ![image.png](attachment:832f11fd-3384-4bab-9658-637e2a36aa4b.png)

# %% [markdown]
# # **4. Задачи на концентрацию и сухое вещество**

# %% [markdown]
# ![image.png](attachment:c8c9339a-c5ad-4dba-a685-00f96e90cbb9.png)

# %% [markdown]
# ![image.png](attachment:eecbb2a8-f9c7-4d35-8dfe-2366747d81e7.png)

# %% [markdown]
# ![image.png](attachment:9c49e41c-6b87-4fa9-84bc-3e0f42ce8eaa.png)

# %% [markdown]
# ![image.png](attachment:4ffc98ee-9bd5-445a-b831-50534d2f009d.png)

# %% [markdown]
# ![image.png](attachment:2603b52a-9b26-4d08-ace8-5cb8bc1993fe.png)

# %% [markdown]
# ![image.png](attachment:dd24a1d6-cf78-4858-9023-91e6dc82c2c2.png)

# %% [markdown]
# ![image.png](attachment:9a72f972-252a-4017-bf72-9c3a8df9ca8b.png)

# %% [markdown]
# # **5. Банковские задачи на проценты**

# %% [markdown]
# ![image.png](attachment:6b1bfb1d-79f1-4a58-b89d-f227abeced46.png)

# %% [markdown]
# ![image.png](attachment:818a5053-c569-4a40-810e-d2543b0ea29f.png)

# %% [markdown]
# ![image.png](attachment:da81f483-70bb-40fb-9014-44d5eff99e13.png)

# %% [markdown]
# ![image.png](attachment:fbd7bbcc-6292-40d2-afc3-ee2058c4164d.png)

# %% [markdown]
# ![image.png](attachment:32f58a84-b62c-4b46-9c00-ddc99c58481e.png)

# %% [markdown]
# ![image.png](attachment:5c20f4d8-de30-4f20-932c-8f47d8e659c4.png)

# %% [markdown]
# ![image.png](attachment:be500138-39ef-4fef-bd69-f938e853dcdb.png)

# %% [markdown]
# ![image.png](attachment:4c116d34-db4c-49c6-a225-5141119fb0ba.png)

# %% [markdown]
# ![image.png](attachment:947f9729-c01c-4a10-b1c0-374b3c0e74bd.png)

# %% [markdown]
# ![image.png](attachment:4a75e959-af91-4ab4-adf5-feddf2a9aded.png)

# %% [markdown]
# ![image.png](attachment:93d01fd0-937e-41c6-a7e8-0d985874396f.png)

# %% [markdown]
# ![image.png](attachment:a86c0d59-87b9-46d4-8958-b5e80d45e1d5.png)

# %% [markdown]
# ![image.png](attachment:f8cc68e1-756a-4f79-89ce-8d792d26c4eb.png)

# %% [markdown]
# ![image.png](attachment:d155571c-6a59-424c-adcb-c8208e687e39.png)

# %% [markdown]
# ![image.png](attachment:2e182a5d-6c40-4d4b-b061-33ed2b6e5255.png)

# %% [markdown]
# ![image.png](attachment:be1cdeb3-4b43-4622-b096-6217a54f56b5.png)

# %% [markdown]
# ![image.png](attachment:e59342ef-cf16-40d2-996a-af0f5d399a6e.png)

# %% [markdown]
# ![image.png](attachment:4b3a76ae-2f8d-4e36-8590-8426d374d212.png)

# %% [markdown]
# ![image.png](attachment:9fc9fded-ec9f-4c32-8f44-0a567c3627e1.png)

# %% [markdown]
# ![image.png](attachment:2bcec22b-311d-4dec-9091-46616cfb6e2f.png)

# %% [markdown]
# ![image.png](attachment:ea93338a-8488-4332-a2be-36b1b1963e12.png)

# %% [markdown]
# ![image.png](attachment:65408b4a-76d5-4b73-b3e5-b4090171ba0d.png)

# %% [markdown]
# ![image.png](attachment:b04c8a16-72d0-4238-b7d8-a58c71c050d5.png)

# %% [markdown]
# ![image.png](attachment:aea9a466-99bb-48e7-a220-caf91201d924.png)

# %% [markdown]
# ![image.png](attachment:dbdb09c3-28d6-4d32-8c70-ba334aee7602.png)

# %% [markdown]
# ![image.png](attachment:ae8e2b0b-98be-4b40-aeae-a345a728611e.png)

# %% [markdown]
# ![image.png](attachment:f72d7df9-6310-4ad3-ba27-c7f205a69241.png)

# %% [markdown]
# ![image.png](attachment:f34c555b-fef6-49d8-88cd-0d8ff7c72f32.png)

# %% [markdown]
# ![image.png](attachment:a3ef5731-2cf6-4559-b580-15bddd994aa0.png)

# %% [markdown]
# ![image.png](attachment:212d6a29-5770-44e6-8869-2e92a6a50bc3.png)
