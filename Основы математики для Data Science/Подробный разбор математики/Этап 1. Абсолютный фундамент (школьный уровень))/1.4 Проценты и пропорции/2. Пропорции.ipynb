# %% [markdown]
# # **Пропорции**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# ![image.png](attachment:64cf9ce1-c3ea-4229-a39e-e364443c87b4.png)

# %% [markdown]
# # **1. Отношения**

# %% [markdown]
# ![image.png](attachment:b85edc14-85f6-4845-ae68-be06ac4879cd.png)

# %% [markdown]
# ![image.png](attachment:789edcf5-bb3f-467f-8aa8-4cd6288a5b1b.png)

# %% [markdown]
# ![image.png](attachment:d99f8197-cdbf-4304-aba7-d7104ecdd452.png)

# %% [markdown]
# ![image.png](attachment:6223aef8-bcf4-44b6-af35-9b6a186319d0.png)

# %% [markdown]
# ![image.png](attachment:e27c2370-5dc1-4afa-b231-c0e8790879f2.png)

# %% [markdown]
# ![image.png](attachment:1f0c30d4-7401-454b-9d9e-d2a6684fd509.png)

# %% [markdown]
# ![image.png](attachment:271de091-a8cb-48ec-9fb6-bd9fc18fa4e2.png)

# %% [markdown]
# ![image.png](attachment:7289fc58-67cf-48cb-89aa-5b3ac1ca0d47.png)

# %% [markdown]
# ![image.png](attachment:4e28e40e-8cc8-42b2-89e3-de8ad8140b71.png)

# %% [markdown]
# ![image.png](attachment:5e68b60e-25db-412a-8941-6c08ac820930.png)

# %% [markdown]
# ![image.png](attachment:eba02456-6a71-4ac0-9969-4e7611b63e5c.png)

# %% [markdown]
# ![image.png](attachment:a0f4b2d4-1858-4acf-80b7-ee6e686c0299.png)

# %% [markdown]
# ![image.png](attachment:276ddd7f-5925-4da5-ae4f-e9cc22a60e06.png)

# %% [markdown]
# # **2. Пропорции**

# %% [markdown]
# ![image.png](attachment:7d2d2dcb-f8cf-42a2-816a-2bc7952cd45d.png)

# %% [markdown]
# ![image.png](attachment:99af0d83-bfdd-4072-80a1-be2510c93677.png)

# %% [markdown]
# ![image.png](attachment:f089d381-63d2-4a8b-b1a0-c03db7cb66e5.png)

# %% [markdown]
# ![image.png](attachment:f8234d94-f85a-4d76-a7c9-f902a274c224.png)

# %% [markdown]
# ![image.png](attachment:e4c473a0-659b-46a3-aa86-a3a1ad675ba4.png)

# %% [markdown]
# ![image.png](attachment:2ffc6359-18c2-42c5-9fde-407687db7bfd.png)

# %% [markdown]
# ![image.png](attachment:3ee6dac9-3377-471f-9187-3d4aab6a1d5d.png)

# %% [markdown]
# ![image.png](attachment:33884c01-2d35-4b7e-a146-a91ce3a195c2.png)

# %% [markdown]
# ![image.png](attachment:a482bbeb-48d2-4be6-98a1-8b4d87fe6a3d.png)

# %% [markdown]
# ![image.png](attachment:ee3631f3-aaf2-4559-b8f8-c1a9ce8492a4.png)

# %% [markdown]
# ![image.png](attachment:84330638-99b0-46c6-9e3e-69cad4495930.png)

# %% [markdown]
# ![image.png](attachment:3f37a42f-8519-42a2-bb31-418730fa405a.png)

# %% [markdown]
# ![image.png](attachment:650f5d19-e702-41dc-9c6a-f13783866c4b.png)

# %% [markdown]
# ![image.png](attachment:e9aac57a-8c79-41f7-a606-15f7794622d0.png)

# %% [markdown]
# ![image.png](attachment:beedbac6-83ea-4061-9801-9c5332918cef.png)

# %% [markdown]
# # **3. Прямая и обратная пропорциональность**

# %% [markdown]
# ![image.png](attachment:8e6bf947-6263-45e2-bd43-f815e3510d11.png)

# %% [markdown]
# ![image.png](attachment:924c00a0-92f9-489f-adfc-e58b275ee786.png)

# %% [markdown]
# ![image.png](attachment:daf4efff-e753-4cfd-92b2-eb1a42a2c2d2.png)

# %% [markdown]
# ![image.png](attachment:454f9821-6f35-4acd-a2f7-9fcbe0162022.png)

# %% [markdown]
# ![image.png](attachment:0b228abf-a892-48fe-be8a-f2cf0e5f9932.png)

# %% [markdown]
# ![image.png](attachment:e07e39fe-e225-4995-a477-eb131829c9df.png)

# %% [markdown]
# ![image.png](attachment:fafb7e2e-59df-45da-9cc8-61662df2ee45.png)

# %% [markdown]
# ![image.png](attachment:acc0487f-0a97-4fe1-bc32-3943761d083b.png)

# %% [markdown]
# ![image.png](attachment:19062dae-3bba-4c39-9f7c-703cd3b7b249.png)
