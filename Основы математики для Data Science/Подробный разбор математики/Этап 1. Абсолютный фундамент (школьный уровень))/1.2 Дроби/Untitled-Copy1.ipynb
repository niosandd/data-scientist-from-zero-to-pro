# %% [markdown]
# # **Действия с обыкновенными дробями**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Дроби"**

# %% [markdown]
# ![image.png](attachment:51e14f6c-4692-4958-82d5-9e4718bb7549.png)

# %% [markdown]
# # **2. Доли и дроби**

# %% [markdown]
# ![image.png](attachment:ba2538bf-6fc6-4902-b7e0-dba91cd42aaf.png)

# %% [markdown]
# ![image.png](attachment:994a0c79-91de-41b1-914d-857d611aeb22.png)

# %% [markdown]
# ![image.png](attachment:cb644b83-8b9b-4b53-9b24-cca81b3d7850.png)

# %% [markdown]
# ![image.png](attachment:d5a2b302-10bb-49be-b689-3ba837d79c23.png)

# %% [markdown]
# ![image.png](attachment:8aec7836-d833-4c20-a7ab-a4b8b857b787.png)

# %% [markdown]
# ![image.png](attachment:d66501cf-a1fc-4498-b689-e5ca8c16e184.png)

# %% [markdown]
# ![image.png](attachment:7d635905-d5c0-4c4c-8bb5-89d29a2a669a.png)

# %% [markdown]
# ![image.png](attachment:03e9f1dd-09b4-4a4f-9c2d-e0a169d6ef90.png)

# %% [markdown]
# ![image.png](attachment:3b1109fb-d9e3-45c9-86fc-df1f61f896b1.png)

# %% [markdown]
# ![image.png](attachment:b51b14f6-02be-4a6e-96a3-27ba22db002f.png)

# %% [markdown]
# ![image.png](attachment:63db6db8-ed57-48d0-9cbf-4c1d2f5d2075.png)

# %% [markdown]
# ![image.png](attachment:9d1d9b04-010d-4e2a-be90-345c8022c854.png)

# %% [markdown]
# ![image.png](attachment:0f88b9cd-36dc-44a2-b74c-d0b909c0b56b.png)

# %% [markdown]
# ![image.png](attachment:e758ea3a-4678-4b12-b5d6-7e55b6322725.png)

# %% [markdown]
# ![image.png](attachment:49d6e80d-bcf5-4a4a-b9fd-aa049c421312.png)

# %% [markdown]
# ![image.png](attachment:71d0521f-4b8d-4352-8809-3462388df4c6.png)

# %% [markdown]
# ![image.png](attachment:7a9244d8-1155-4c74-8f49-9c1d36214715.png)

# %% [markdown]
# ![image.png](attachment:a02d652b-f21a-453b-84ea-bf2889593583.png)

# %% [markdown]
# ![image.png](attachment:11f5406e-4e9b-4ac0-a8d7-5ebdd7d721a9.png)

# %% [markdown]
# ![image.png](attachment:5244c7e5-14fd-47c3-ab83-b5f835f29146.png)

# %% [markdown]
# ![image.png](attachment:e221350a-fc69-4c4f-b8fe-788e3033f5fc.png)

# %% [markdown]
# ![image.png](attachment:219e2b32-8d32-479e-9294-e4686a6ddf4c.png)

# %% [markdown]
# # **3. Основное свойство дроби**

# %% [markdown]
# ![image.png](attachment:26caf48d-4702-45b4-b656-4e87c87ba854.png)

# %% [markdown]
# ![image.png](attachment:94ecf21e-54ac-4395-8df9-5e7edea62733.png)

# %% [markdown]
# ![image.png](attachment:99d58c42-6201-4761-bb7d-e0abe7ebd225.png)

# %% [markdown]
# ![image.png](attachment:73f0130d-ecb1-45d4-b85a-f25e8b3e8f2a.png)

# %% [markdown]
# ![image.png](attachment:d00c6f55-3eee-4e6e-b32d-22831f55f816.png)

# %% [markdown]
# ![image.png](attachment:ecb4db21-bf70-4475-9400-a9ac4ddbfebb.png)

# %% [markdown]
# ![image.png](attachment:375326cb-623f-444b-896d-e373ee2eefb5.png)

# %% [markdown]
# ![image.png](attachment:b25e24b6-d622-4477-90a8-fee9fbafa3ba.png)

# %% [markdown]
# ![image.png](attachment:6c5d1cbc-7ed8-4d33-846e-7effe6f0ca88.png)

# %% [markdown]
# ![image.png](attachment:36e9286a-4317-4c45-a957-5b258e4639de.png)

# %% [markdown]
# ![image.png](attachment:83c141a5-5dd3-40e7-b920-a8d56c9bfea2.png)
