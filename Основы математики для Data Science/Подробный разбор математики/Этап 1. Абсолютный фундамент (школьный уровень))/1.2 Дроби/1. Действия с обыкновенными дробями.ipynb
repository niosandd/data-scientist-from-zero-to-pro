# %% [markdown]
# # **Действия с обыкновенными дробями**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Дроби"**

# %% [markdown]
# ![image.png](attachment:51e14f6c-4692-4958-82d5-9e4718bb7549.png)

# %% [markdown]
# # **2. Доли и дроби**

# %% [markdown]
# ![image.png](attachment:ba2538bf-6fc6-4902-b7e0-dba91cd42aaf.png)

# %% [markdown]
# ![image.png](attachment:994a0c79-91de-41b1-914d-857d611aeb22.png)

# %% [markdown]
# ![image.png](attachment:cb644b83-8b9b-4b53-9b24-cca81b3d7850.png)

# %% [markdown]
# ![image.png](attachment:d5a2b302-10bb-49be-b689-3ba837d79c23.png)

# %% [markdown]
# ![image.png](attachment:8aec7836-d833-4c20-a7ab-a4b8b857b787.png)

# %% [markdown]
# ![image.png](attachment:d66501cf-a1fc-4498-b689-e5ca8c16e184.png)

# %% [markdown]
# ![image.png](attachment:7d635905-d5c0-4c4c-8bb5-89d29a2a669a.png)

# %% [markdown]
# ![image.png](attachment:03e9f1dd-09b4-4a4f-9c2d-e0a169d6ef90.png)

# %% [markdown]
# ![image.png](attachment:3b1109fb-d9e3-45c9-86fc-df1f61f896b1.png)

# %% [markdown]
# ![image.png](attachment:b51b14f6-02be-4a6e-96a3-27ba22db002f.png)

# %% [markdown]
# ![image.png](attachment:63db6db8-ed57-48d0-9cbf-4c1d2f5d2075.png)

# %% [markdown]
# ![image.png](attachment:9d1d9b04-010d-4e2a-be90-345c8022c854.png)

# %% [markdown]
# ![image.png](attachment:0f88b9cd-36dc-44a2-b74c-d0b909c0b56b.png)

# %% [markdown]
# ![image.png](attachment:e758ea3a-4678-4b12-b5d6-7e55b6322725.png)

# %% [markdown]
# ![image.png](attachment:49d6e80d-bcf5-4a4a-b9fd-aa049c421312.png)

# %% [markdown]
# ![image.png](attachment:71d0521f-4b8d-4352-8809-3462388df4c6.png)

# %% [markdown]
# ![image.png](attachment:7a9244d8-1155-4c74-8f49-9c1d36214715.png)

# %% [markdown]
# ![image.png](attachment:a02d652b-f21a-453b-84ea-bf2889593583.png)

# %% [markdown]
# ![image.png](attachment:11f5406e-4e9b-4ac0-a8d7-5ebdd7d721a9.png)

# %% [markdown]
# ![image.png](attachment:5244c7e5-14fd-47c3-ab83-b5f835f29146.png)

# %% [markdown]
# ![image.png](attachment:e221350a-fc69-4c4f-b8fe-788e3033f5fc.png)

# %% [markdown]
# ![image.png](attachment:219e2b32-8d32-479e-9294-e4686a6ddf4c.png)

# %% [markdown]
# # **3. Основное свойство дроби**

# %% [markdown]
# ![image.png](attachment:26caf48d-4702-45b4-b656-4e87c87ba854.png)

# %% [markdown]
# ![image.png](attachment:94ecf21e-54ac-4395-8df9-5e7edea62733.png)

# %% [markdown]
# ![image.png](attachment:99d58c42-6201-4761-bb7d-e0abe7ebd225.png)

# %% [markdown]
# ![image.png](attachment:73f0130d-ecb1-45d4-b85a-f25e8b3e8f2a.png)

# %% [markdown]
# ![image.png](attachment:d00c6f55-3eee-4e6e-b32d-22831f55f816.png)

# %% [markdown]
# ![image.png](attachment:ecb4db21-bf70-4475-9400-a9ac4ddbfebb.png)

# %% [markdown]
# ![image.png](attachment:375326cb-623f-444b-896d-e373ee2eefb5.png)

# %% [markdown]
# ![image.png](attachment:b25e24b6-d622-4477-90a8-fee9fbafa3ba.png)

# %% [markdown]
# ![image.png](attachment:6c5d1cbc-7ed8-4d33-846e-7effe6f0ca88.png)

# %% [markdown]
# ![image.png](attachment:36e9286a-4317-4c45-a957-5b258e4639de.png)

# %% [markdown]
# ![image.png](attachment:83c141a5-5dd3-40e7-b920-a8d56c9bfea2.png)

# %% [markdown]
# ![image.png](attachment:5c001a48-4806-4bce-9fee-6831e4d8fbf3.png)

# %% [markdown]
# ![image.png](attachment:b8acd7af-f4ca-4da1-bb03-f063ef36fdef.png)

# %% [markdown]
# # **4. Сравнение дробей**

# %% [markdown]
# ![image.png](attachment:35005b4b-3bb5-4814-b2ff-7a978677be17.png)

# %% [markdown]
# ![image.png](attachment:e1f4da90-ced3-4cd3-804f-4d608de82be7.png)

# %% [markdown]
# ![image.png](attachment:dbe89b0d-52ad-48c4-942f-fe34bcf06b24.png)

# %% [markdown]
# ![image.png](attachment:8da8f2b9-f1cc-4902-89ef-d19fef129536.png)

# %% [markdown]
# ![image.png](attachment:aaa7ea41-2f30-452a-9621-fc08b2276f99.png)

# %% [markdown]
# ![image.png](attachment:254eef40-5c95-4d10-9394-02a765ff694c.png)

# %% [markdown]
# ![image.png](attachment:a756531c-6165-4e50-b2b0-4380962266f7.png)

# %% [markdown]
# ![image.png](attachment:0ca84621-45d7-4c5c-8462-f8fe3cd3da3e.png)

# %% [markdown]
# ![image.png](attachment:7fd949a1-9a72-4e54-8729-0a0b41361c9e.png)

# %% [markdown]
# ![image.png](attachment:ba28f5e9-64dc-4824-a339-4cd76b282d5a.png)

# %% [markdown]
# ![image.png](attachment:043e6f77-b6a6-41bb-a122-e1e96aa098e8.png)

# %% [markdown]
# ![image.png](attachment:58d0abd3-ed4f-45a2-bf6a-8cac2fae25a0.png)

# %% [markdown]
# ![image.png](attachment:acb7312c-b768-4192-8665-acca493f2ab8.png)

# %% [markdown]
# ![image.png](attachment:eca7536e-fb6d-4f27-992a-f9a99cbff58a.png)

# %% [markdown]
# ![image.png](attachment:3391c25b-6071-4362-81f0-f6a751fcbd2d.png)

# %% [markdown]
# ![image.png](attachment:42fbfce7-43c3-47e2-b6ed-2cb2a6edca09.png)

# %% [markdown]
# ![image.png](attachment:a9ca0d9c-d886-4712-aef2-779b9c282721.png)

# %% [markdown]
# # **5. Сложение и вычитание обыкновенных дробей**

# %% [markdown]
# ![image.png](attachment:ffbaea6c-c869-40f5-ac9a-810bb26cf958.png)

# %% [markdown]
# ![image.png](attachment:94723b6f-96e7-4b55-881a-3191b3c704bd.png)

# %% [markdown]
# ![image.png](attachment:010c2be2-fc01-4098-96f6-a597747ee614.png)

# %% [markdown]
# ![image.png](attachment:c748777f-39be-4e13-bcf9-734e9751ae2f.png)

# %% [markdown]
# ![image.png](attachment:fa3c2430-f7fa-4981-8457-fc3e85e1f66c.png)

# %% [markdown]
# ![image.png](attachment:7b1529f2-7412-4979-a576-677a11b3f35c.png)

# %% [markdown]
# ![image.png](attachment:aa3f4963-0611-4cb9-ad19-d8bf74f9d6d2.png)

# %% [markdown]
# # **6. Умножение обыкновенных дробей**

# %% [markdown]
# ![image.png](attachment:ab293a61-dbf6-4b6e-8ac6-2a6cb40e7ce1.png)

# %% [markdown]
# ![image.png](attachment:2aa83733-8a54-4e02-9cde-59a38e4a754e.png)

# %% [markdown]
# ![image.png](attachment:3cd7b177-e622-4182-a77b-8aaa392bfc5d.png)

# %% [markdown]
# ![image.png](attachment:231d7cdf-1525-435a-9a17-4cc9693d2f3a.png)

# %% [markdown]
# ![image.png](attachment:dd81aca1-9655-49fe-8656-1d32063facaa.png)

# %% [markdown]
# ![image.png](attachment:1ef20ac5-2cdd-4a0e-b868-f2369971c7bd.png)

# %% [markdown]
# ![image.png](attachment:03247979-a991-4173-a650-e2fd35dc8822.png)

# %% [markdown]
# ![image.png](attachment:320c859b-004f-41bd-88a5-8f2d3c6fb2a5.png)

# %% [markdown]
# ![image.png](attachment:fb75f223-940c-4058-8109-dc1a3e7c66d8.png)

# %% [markdown]
# ![image.png](attachment:198b6216-1ed8-41e4-9fc3-eba4c849c650.png)

# %% [markdown]
# ![image.png](attachment:e500c4f2-425f-419b-9449-c276a91a638f.png)

# %% [markdown]
# # **7. Деление обыкновенных дробей**

# %% [markdown]
# ![image.png](attachment:4739a940-3c3d-4920-a6fc-a34503e2694e.png)

# %% [markdown]
# ![image.png](attachment:c893db77-a8e1-4651-8461-c1fdb67e8eee.png)

# %% [markdown]
# ![image.png](attachment:b703f4ac-f93e-4465-b796-c41df30e7273.png)

# %% [markdown]
# ![image.png](attachment:07ec834e-606f-424a-8664-dcdbc0a884a2.png)

# %% [markdown]
# ![image.png](attachment:dcf6060a-d710-452e-80af-48e62c008ba7.png)

# %% [markdown]
# ![image.png](attachment:515e8c66-48a0-4614-aa7c-547918d98589.png)

# %% [markdown]
# ![image.png](attachment:ce834c18-132c-4752-b9c6-ab60b9456705.png)

# %% [markdown]
# ![image.png](attachment:c76a949c-8a33-4503-b232-655e3d802d5f.png)

# %% [markdown]
# ![image.png](attachment:8390f661-7ce7-459b-8fdc-28773eca2699.png)

# %% [markdown]
# ![image.png](attachment:8789dcce-7914-49e5-9691-3964ebbcbfd3.png)

# %% [markdown]
# ![image.png](attachment:21cb0829-ac95-4d21-acc4-4bac77b6458d.png)

# %% [markdown]
# ![image.png](attachment:896265f2-83a8-4ca7-bae3-4a75264ed1d1.png)

# %% [markdown]
# ![image.png](attachment:ed18cb08-3a27-4ac7-84b5-c9f71bad67a7.png)

# %% [markdown]
# ![image.png](attachment:66563f68-559c-4333-baf2-51d40e7725fe.png)

# %% [markdown]
# ![image.png](attachment:aad5e628-6987-4916-836a-333e0bf46b27.png)

# %% [markdown]
# ![image.png](attachment:cce89401-eed3-4ea1-b5b0-d7a474993b67.png)

# %% [markdown]
# ![image.png](attachment:18572b8f-2750-4956-96af-23bc2eceba39.png)
