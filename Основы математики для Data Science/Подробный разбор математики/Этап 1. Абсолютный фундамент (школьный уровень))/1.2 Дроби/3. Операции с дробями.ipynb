# %% [markdown]
# # **Операция с дробями**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Операция с дробями"**

# %% [markdown]
# ![image.png](attachment:1c97e7aa-733c-482f-b41e-dfb88ffd3cfa.png)

# %% [markdown]
# # **2. Действия с обыкновенными и десятичными дробями**

# %% [markdown]
# ![image.png](attachment:b35b7eed-dc02-4ad1-b311-32203b63fab7.png)

# %% [markdown]
# ![image.png](attachment:ae488595-c9e5-4537-b485-ab5e11f80195.png)

# %% [markdown]
# ![image.png](attachment:6549342a-58ea-443c-a994-6fdc35f6d098.png)

# %% [markdown]
# ![image.png](attachment:6f9d5bf4-dcf7-4821-95bf-4a3ac212d1ce.png)

# %% [markdown]
# ![image.png](attachment:fc48c463-7f33-469a-a3bd-d03e72768f57.png)

# %% [markdown]
# ![image.png](attachment:9de88373-78f5-4992-99d4-8d2833bc5704.png)

# %% [markdown]
# ![image.png](attachment:9bc75e07-34ce-4c2c-b625-378d1efd5013.png)

# %% [markdown]
# ![image.png](attachment:3301fd07-cb0b-4fbe-b91a-59b49bbf5181.png)

# %% [markdown]
# ![image.png](attachment:f5d4c731-e2a7-4cda-b939-cd9c93373d7a.png)

# %% [markdown]
# ![image.png](attachment:2ef1e799-6ccb-4139-a90f-91ff3081fc88.png)

# %% [markdown]
# ![image.png](attachment:bcc86fb5-548e-466a-adbf-af5f2a2c5314.png)

# %% [markdown]
# ![image.png](attachment:0e8cee0a-7a24-4615-9307-86bfae5c03f7.png)

# %% [markdown]
# ![image.png](attachment:48dd6479-93e8-477c-85ef-1928f6cb3b15.png)

# %% [markdown]
# ![image.png](attachment:d951edbc-53da-4fa9-9dc2-fc05e4747838.png)

# %% [markdown]
# ![image.png](attachment:bc210de4-a45a-4017-9266-e06c7285263f.png)

# %% [markdown]
# ![image.png](attachment:03e0a426-01ee-4f9e-bf53-d99e0d10ddba.png)

# %% [markdown]
# ![image.png](attachment:8c564800-b901-4b7b-8805-cf2dc6174678.png)

# %% [markdown]
# ![image.png](attachment:e42f9e72-0195-4c79-b1e8-5be9971aacb8.png)

# %% [markdown]
# ![image.png](attachment:88c178a5-247c-4a8d-bc1e-f3b20ef7f7ed.png)

# %% [markdown]
# ![image.png](attachment:6bf52c94-6d78-4af2-a3b5-07d0f9f10eb3.png)

# %% [markdown]
# # **3. Целая отрицательная степень**

# %% [markdown]
# ![image.png](attachment:3416d2bc-93be-450a-98d3-a0cb2c45be8c.png)

# %% [markdown]
# ![image.png](attachment:d1e003da-8fcc-4357-a28d-6e1c20a1467b.png)

# %% [markdown]
# ![image.png](attachment:60f57ae3-e0ac-4ee0-9b06-00d36535c0f2.png)

# %% [markdown]
# ![image.png](attachment:d0e4f3cc-73ec-4520-942b-1bcb7f431f65.png)

# %% [markdown]
# ![image.png](attachment:804ed829-c53d-4426-a3a3-5457a8b29356.png)

# %% [markdown]
# ![image.png](attachment:f3699704-3eb8-4b83-a111-51b7c9b6c2ca.png)

# %% [markdown]
# ![image.png](attachment:bf8e494c-ef01-4e5d-9bf8-ffa6643ce3ee.png)

# %% [markdown]
# ![image.png](attachment:ea81a953-7504-44be-b17c-f57e3267f61b.png)

# %% [markdown]
# ![image.png](attachment:8e1a5984-d63f-4fdc-9b9f-ebfa429b9867.png)

# %% [markdown]
# ![image.png](attachment:b1e09c60-210d-4772-9e13-a2a8cd0b3669.png)

# %% [markdown]
# ![image.png](attachment:6273c5e1-ad57-4b66-af06-3f9c76ce4714.png)

# %% [markdown]
# ![image.png](attachment:54d40458-93a4-4e5f-a3d6-f5085ef7d443.png)

# %% [markdown]
# ![image.png](attachment:43070d36-ffd9-4bb9-b8dc-7cf916cd03ce.png)

# %% [markdown]
# ![image.png](attachment:9400e78e-475d-4560-a37e-132a7bab1c80.png)

# %% [markdown]
# ![image.png](attachment:2ec47721-cace-4776-9206-751c21b9d6ba.png)

# %% [markdown]
# ![image.png](attachment:af1805c2-d60b-4f8c-b56d-8d18645e632b.png)

# %% [markdown]
# ![image.png](attachment:e268a10a-f3d5-481f-8183-38b34cf47742.png)

# %% [markdown]
# ![image.png](attachment:45cec851-cf92-4d94-81a8-683f395cc044.png)

# %% [markdown]
# # **4. Стандартный вид числа**

# %% [markdown]
# ![image.png](attachment:93f87034-eb55-4cb1-85fe-d7ea822292a8.png)

# %% [markdown]
# ![image.png](attachment:af1f3da0-455b-45a4-80f0-99ab7bac9e45.png)

# %% [markdown]
# ![image.png](attachment:5288044f-3007-443a-916a-3dcb2af149b5.png)

# %% [markdown]
# ![image.png](attachment:e5db3f9d-5c18-4230-9ca3-f4e9147a79b1.png)

# %% [markdown]
# ![image.png](attachment:bd85328f-3847-44b2-aef0-f40e37056e9a.png)

# %% [markdown]
# ![image.png](attachment:eaa1debe-5c74-408e-8b67-7a900c6d2508.png)

# %% [markdown]
# ![image.png](attachment:02af4b17-9dfe-4e97-a1a3-39d1705f1f78.png)

# %% [markdown]
# ![image.png](attachment:75baf416-3a7a-410d-a7e6-714d83c743a9.png)

# %% [markdown]
# ![image.png](attachment:5e5d79a0-8692-4caf-98b0-ccaa3950f8f4.png)

# %% [markdown]
# ![image.png](attachment:e62558aa-966c-4c47-8d21-fff05d2c972a.png)

# %% [markdown]
# ![image.png](attachment:7018c5ee-8ee7-4ec8-8e71-ce4f3b53902d.png)

# %% [markdown]
# ![image.png](attachment:d4e07866-4f2d-40fb-a109-c4beee541520.png)

# %% [markdown]
# ![image.png](attachment:00ffbe37-6ccd-491a-8254-559ad6c131fc.png)

# %% [markdown]
# ![image.png](attachment:2f5baa05-26ca-46c1-802f-ee577e289d7a.png)

# %% [markdown]
# # **5. Перевод величин**

# %% [markdown]
# ![image.png](attachment:bc67feb2-ca56-4679-a537-25a1324b25db.png)

# %% [markdown]
# ![image.png](attachment:d187c353-c6f0-4e0b-b164-5822afb93b4d.png)

# %% [markdown]
# ![image.png](attachment:9b41f96a-9ee7-4992-a758-bc35a80b6835.png)

# %% [markdown]
# ![image.png](attachment:9db72bab-315b-47c2-8543-5607c4d7b41b.png)

# %% [markdown]
# ![image.png](attachment:b977b2c4-922c-4aff-89a9-9f50f4b3b731.png)

# %% [markdown]
# ![image.png](attachment:c508ba7f-4116-453a-81c0-7a3174197af4.png)

# %% [markdown]
# ![image.png](attachment:eb3676dc-e372-4e83-9148-74a0a51f45b9.png)

# %% [markdown]
# ![image.png](attachment:f8e0c886-3b86-4f53-a9f2-9a398664ca47.png)

# %% [markdown]
# ![image.png](attachment:a7af2993-7df6-4dc9-8027-86edb6ad9735.png)

# %% [markdown]
# ![image.png](attachment:700e85a5-56c2-4dd6-89ed-f6cb53c34d92.png)

# %% [markdown]
# ![image.png](attachment:7638be31-f76c-4cee-b94c-180410b85bd1.png)

# %% [markdown]
# ![image.png](attachment:d42814e6-03c1-4ab2-a2df-a64ddccc2845.png)

# %% [markdown]
# ![image.png](attachment:d84f9b60-a731-4979-a97c-049fb0ce0136.png)

# %% [markdown]
# ![image.png](attachment:2a3330e8-eb47-41c1-a08f-b781fa2e2c0e.png)

# %% [markdown]
# ![image.png](attachment:ac1cadf4-02f5-4ded-aa82-814fe908ff85.png)

# %% [markdown]
# ![image.png](attachment:5176bf0f-13c9-4b3c-8c3b-867e33538ee4.png)

# %% [markdown]
# ![image.png](attachment:12db321a-7016-4a9c-a926-2db0870738ed.png)

# %% [markdown]
# ![image.png](attachment:671f5b6b-3396-4ef0-8b06-79d4cb31086c.png)

# %% [markdown]
# ![image.png](attachment:c91e0d73-306b-42b9-bce2-15bd74185ff3.png)

# %% [markdown]
# ![image.png](attachment:495eabde-ae6c-4ed0-afc1-739b851bd7da.png)

# %% [markdown]
# ![image.png](attachment:b0a66768-16df-4ae2-92f7-f5a3c5d1263b.png)

# %% [markdown]
# ![image.png](attachment:d9186d71-5452-4100-96cb-71329afebe44.png)

# %% [markdown]
# ![image.png](attachment:33513971-fa23-4645-8749-f98c67f242b9.png)

# %% [markdown]
# ![image.png](attachment:d584b1b1-b5d3-48e8-be62-23be14048375.png)

# %% [markdown]
# ![image.png](attachment:093143c3-7759-44e2-9559-cbfe1e1bb34b.png)

# %% [markdown]
# ![image.png](attachment:3d2bc573-d325-4cb6-8a93-4faa96238f39.png)

# %% [markdown]
# ![image.png](attachment:fcd383b5-8991-400e-ba93-f638a6466af7.png)
