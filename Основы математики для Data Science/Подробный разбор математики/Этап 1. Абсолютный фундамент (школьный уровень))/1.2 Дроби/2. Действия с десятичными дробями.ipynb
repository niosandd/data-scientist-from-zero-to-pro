# %% [markdown]
# # **Действия с десятичными дробями**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Действия с десятичными дробями"**

# %% [markdown]
# ![image.png](attachment:3ee713a5-3c7a-47cf-bf60-62e00eae95cd.png)

# %% [markdown]
# # **2. Понятие десятичной дроби**

# %% [markdown]
# ![image.png](attachment:0b247ed1-af5f-4478-a289-9c1fc00fd7c5.png)

# %% [markdown]
# ![image.png](attachment:48c5224a-016f-4eb7-8788-625b6a6f1949.png)

# %% [markdown]
# ![image.png](attachment:384fb00d-2d41-4ab7-bc0d-52473309bb94.png)

# %% [markdown]
# ![image.png](attachment:f2c37d55-7f46-4790-9432-921f97003a7a.png)

# %% [markdown]
# ![image.png](attachment:4854f359-92dd-4e47-8dfb-6c4f0bd76292.png)

# %% [markdown]
# ![image.png](attachment:b7b01772-969a-417e-bf1d-83d1103aaf3d.png)

# %% [markdown]
# ![image.png](attachment:b3af89f6-49f7-434b-83dc-152f0b9a4433.png)

# %% [markdown]
# ![image.png](attachment:3f6a6321-3897-4091-93e6-d395c977e976.png)

# %% [markdown]
# ![image.png](attachment:15c32708-d24a-4fcc-8271-3655472ad0e3.png)

# %% [markdown]
# ![image.png](attachment:cdf38778-66c6-4950-9723-407b77487780.png)

# %% [markdown]
# ![image.png](attachment:c0fc560a-0f35-4c94-90dd-c6cf1cf06014.png)

# %% [markdown]
# # **3. Сложение и вычитание десятичных дробей**

# %% [markdown]
# ![image.png](attachment:f9ddcbe3-7fa6-4da1-bef8-cbee97b47652.png)

# %% [markdown]
# ![image.png](attachment:642d0a81-33f9-4333-b759-5f2b692150b4.png)

# %% [markdown]
# ![image.png](attachment:4d6968b9-dab0-4c43-adb7-72c373c1a7b4.png)

# %% [markdown]
# ![image.png](attachment:fd8547f1-594e-4b86-b6ca-eba17491052d.png)

# %% [markdown]
# ![image.png](attachment:4d9416e9-c0a1-4a9f-b089-fbf396f5c123.png)

# %% [markdown]
# ![image.png](attachment:863ad5ad-4c2f-4c31-a2b0-e5a1c574d56f.png)

# %% [markdown]
# ![image.png](attachment:ff60e326-6459-4198-a22d-c82b14f4be9c.png)

# %% [markdown]
# ![image.png](attachment:24dd8889-7b59-491f-88ce-f99c16e05e89.png)

# %% [markdown]
# ![image.png](attachment:05cd9513-443d-4c4e-a616-308088a65e63.png)

# %% [markdown]
# ![image.png](attachment:832956e5-f4e9-48b2-a0c8-170b9620fd5d.png)

# %% [markdown]
# # **4. Умножение десятичных дробей**

# %% [markdown]
# ![image.png](attachment:f5f61e63-13ba-40a7-a1fb-8f3e840c5f87.png)

# %% [markdown]
# ![image.png](attachment:7de661d1-14ef-4840-8b7e-06cdbcdec54d.png)

# %% [markdown]
# ![image.png](attachment:5a26a639-920c-461c-a80a-aa989ddccb00.png)

# %% [markdown]
# ![image.png](attachment:59eb542c-2c35-4bb1-9d92-fe2b8a36e041.png)

# %% [markdown]
# ![image.png](attachment:2d0f4674-7526-4a9a-8c0a-58d6403f8238.png)

# %% [markdown]
# ![image.png](attachment:6c1ec384-9738-45e6-b489-3187ab46debb.png)

# %% [markdown]
# ![image.png](attachment:35edb7cf-6174-4e5f-b7f6-a90927328dc3.png)

# %% [markdown]
# ![image.png](attachment:318f1b38-fc16-4cae-b3e1-2996894cdb18.png)

# %% [markdown]
# ![image.png](attachment:ddf89bf7-f2a0-40f4-a02a-f25e18aec288.png)

# %% [markdown]
# # **5. Деление десятичных дробей**

# %% [markdown]
# ![image.png](attachment:8d06e0ba-098f-4046-a6f1-6ee50b65148e.png)

# %% [markdown]
# ![image.png](attachment:bb2bcead-1f69-4b61-b996-221a7d1dab56.png)

# %% [markdown]
# ![image.png](attachment:43d1cee2-64f9-4475-b806-936d4e9d4fd8.png)

# %% [markdown]
# ![image.png](attachment:1ddfbef5-411a-49d1-85b7-606214a0710d.png)

# %% [markdown]
# ![image.png](attachment:a797a85c-f283-4554-95b4-9654c15495e5.png)

# %% [markdown]
# ![image.png](attachment:c77c64b5-3084-4973-9285-15da4243902b.png)

# %% [markdown]
# ![image.png](attachment:a8e86a8d-2c92-4e50-8ca6-2172c9e29c3b.png)

# %% [markdown]
# ![image.png](attachment:0a4deeb1-0859-49db-beca-c86fde9a55c7.png)

# %% [markdown]
# ![image.png](attachment:09e7c19f-ea0f-4bad-97f2-27bd9728b271.png)

# %% [markdown]
# ![image.png](attachment:44e1c6d4-6eee-4aaa-9222-37bdcc907297.png)

# %% [markdown]
# ![image.png](attachment:8d1eafd4-a5a5-46db-bd9d-4e192a71cfda.png)

# %% [markdown]
# ![image.png](attachment:9b55873d-75c8-464f-91ae-9852fb4c2965.png)

# %% [markdown]
# ![image.png](attachment:31a3a18b-570b-4593-8d7a-ed5c94601b1b.png)

# %% [markdown]
# ![image.png](attachment:8bfd438a-3b8d-42d8-94b7-94b40a2fae21.png)

# %% [markdown]
# ![image.png](attachment:5aaff926-ef6d-44a4-801c-1852b572d027.png)

# %% [markdown]
# # **6. Конечные и бесконечные десятичные дроби**

# %% [markdown]
# ![image.png](attachment:a7890691-e234-48d8-927b-414eb94cad11.png)

# %% [markdown]
# ![image.png](attachment:5136dc76-8c2f-4889-bd34-69969b33de00.png)

# %% [markdown]
# ![image.png](attachment:6e30f8b2-0c0f-4aa6-8fd2-be48362e3ee9.png)

# %% [markdown]
# ![image.png](attachment:319b2193-7cc8-497b-9ddd-063699622459.png)

# %% [markdown]
# ![image.png](attachment:0adb9760-f93f-4a3c-a4df-5aca2e72331e.png)

# %% [markdown]
# ![image.png](attachment:eb142fae-8fd5-4e38-bf3c-422c341f0ef4.png)

# %% [markdown]
# ![image.png](attachment:da7e2fdc-4b8b-4e53-85f6-3c5619fc09f7.png)

# %% [markdown]
# ![image.png](attachment:c8bfbd19-df31-44ad-99c0-6e1e07b92519.png)

# %% [markdown]
# ![image.png](attachment:716a5410-8024-4d64-909c-6fd45e5c2a45.png)

# %% [markdown]
# ![image.png](attachment:66292378-92c8-4897-ae4a-f3cf1b877093.png)

# %% [markdown]
# ![image.png](attachment:8de480d5-592b-419d-a139-450e18079ce6.png)

# %% [markdown]
# ![image.png](attachment:17cd24a7-c7ab-4a19-ba47-0a849630879b.png)

# %% [markdown]
# ![image.png](attachment:b6c00f9b-ffbd-44b4-8ae3-38157f15fed1.png)

# %% [markdown]
# ![image.png](attachment:c4876956-a0c7-4c04-9db2-1208d398c81c.png)

# %% [markdown]
# ![image.png](attachment:93e47a18-b5f7-4c65-8b44-f47b378e4308.png)

# %% [markdown]
# ![image.png](attachment:0d38804b-7d8e-4619-9fae-fe491af63856.png)

# %% [markdown]
# ![image.png](attachment:bc63daf2-f3d3-4ce7-b6f9-a8e9f754294e.png)

# %% [markdown]
# ![image.png](attachment:e1379c56-9019-43ec-b838-1d1689425b2c.png)

# %% [markdown]
# ![image.png](attachment:92137afe-d88f-4156-8f74-ec9e6f1787b9.png)

# %% [markdown]
# ![image.png](attachment:bf520837-58b4-4b1b-b496-edee3f425f98.png)

# %% [markdown]
# ![image.png](attachment:da244722-4346-4acb-a80e-5f4907fe46f6.png)

# %% [markdown]
# ![image.png](attachment:6faff2d0-8566-4a4b-86cd-4ad34d23844c.png)

# %% [markdown]
# ![image.png](attachment:1eaebd72-fa1f-42ca-9b84-d34b89ef467a.png)

# %% [markdown]
# ![image.png](attachment:9396ee66-c231-4799-b712-4f92910ffcd5.png)

# %% [markdown]
# ![image.png](attachment:944e59b4-50e0-4b36-8bbc-82e0762276c3.png)

# %% [markdown]
# ![image.png](attachment:60058b9f-058b-4a66-bbec-c3413d0cca09.png)

# %% [markdown]
# ![image.png](attachment:66a01861-5dd1-41cc-911c-f12b1a7fbbef.png)
