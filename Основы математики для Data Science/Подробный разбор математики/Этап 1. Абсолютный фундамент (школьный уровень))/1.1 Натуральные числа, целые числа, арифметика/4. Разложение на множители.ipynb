# %% [markdown]
# # **Разложение на множители**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Действия с целыми числами"**

# %% [markdown]
# ![image.png](attachment:367b141f-80cf-4eb0-a99d-b83618e3b5b4.png)

# %% [markdown]
# # **2. Целые числа**

# %% [markdown]
# ![image.png](attachment:64b11bba-26c4-481a-9641-8001da154c0c.png)

# %% [markdown]
# ![image.png](attachment:8ddac04e-e164-4788-b8c4-b78a68ed4bcf.png)

# %% [markdown]
# ![image.png](attachment:0e1c7f52-4d59-4883-b8fc-9dcfec919884.png)

# %% [markdown]
# ![image.png](attachment:67f59d90-7f2b-4e6f-814b-9d9a4732dd36.png)

# %% [markdown]
# ![image.png](attachment:b3170b6e-d977-46df-a925-77a25bd719fe.png)

# %% [markdown]
# ![image.png](attachment:9867b934-8f76-40be-a25e-68a6db879f30.png)

# %% [markdown]
# ![image.png](attachment:2fdeec89-c63a-4939-b2d2-956fa763b1d2.png)

# %% [markdown]
# ![image.png](attachment:f8267c6f-b0ad-4825-b96a-ac498c170295.png)

# %% [markdown]
# ![image.png](attachment:f770fcc5-8b4e-4b26-b91b-3533fe71c5d0.png)

# %% [markdown]
# ![image.png](attachment:c526c4e4-957c-42a4-9e14-bab6d3783bf2.png)

# %% [markdown]
# ![image.png](attachment:79ae4963-84e2-427f-ad71-1c9c76f4ca49.png)

# %% [markdown]
# ![image.png](attachment:2f5c4c05-fd58-43e2-9b5f-cd264e23a3ba.png)

# %% [markdown]
# ![image.png](attachment:f0e4ea77-efe9-44b0-b9a2-8d98fa10cbe0.png)

# %% [markdown]
# ![image.png](attachment:e4c01be4-d268-4098-b402-17b7ec56c1fb.png)

# %% [markdown]
# ![image.png](attachment:980f3520-8521-49af-af06-dea6d824fbf2.png)

# %% [markdown]
# ![image.png](attachment:90f47f0e-ca53-4898-bfaf-85d65c33d981.png)

# %% [markdown]
# # **3. Модули и скобки**

# %% [markdown]
# ![image.png](attachment:4b7dd29b-be15-431b-a129-9589c9505abf.png)

# %% [markdown]
# ![image.png](attachment:0194821a-2295-4392-92a6-9730bed479a5.png)

# %% [markdown]
# ![image.png](attachment:28a0261a-6c3d-4d00-b165-5bbe0904aa35.png)

# %% [markdown]
# ![image.png](attachment:c3c16386-9b97-48f4-8feb-186c47b1ef67.png)

# %% [markdown]
# ![image.png](attachment:bec1a582-2400-4d53-9dc6-5467a4ae736c.png)

# %% [markdown]
# ![image.png](attachment:66fab4bc-ea44-4f92-9bae-36101fc522d1.png)

# %% [markdown]
# ![image.png](attachment:c003c9e8-432f-4e3f-8b09-263ab6ca0c1b.png)

# %% [markdown]
# ![image.png](attachment:9635c116-6c53-4267-b7b0-347487485cb8.png)

# %% [markdown]
# ![image.png](attachment:c9bbb81a-80fd-4f59-b812-2e267c51a3e8.png)

# %% [markdown]
# ![image.png](attachment:18d1213a-b394-40ae-9cf0-256b7b69e125.png)

# %% [markdown]
# ![image.png](attachment:d48e91b7-69b9-4fcf-9343-1ec002e866da.png)

# %% [markdown]
# # **4. Сложение целых чисел**

# %% [markdown]
# ![image.png](attachment:22b8f71c-a880-46bc-b6e1-4aac7661f328.png)

# %% [markdown]
# ![image.png](attachment:03fea046-8913-4780-9fa0-b90fc8f08d55.png)

# %% [markdown]
# ![image.png](attachment:dd6fb54e-bd89-429e-aae9-723ae084852a.png)

# %% [markdown]
# ![image.png](attachment:da889180-8765-4720-8da2-77d5d2b03e7b.png)

# %% [markdown]
# ![image.png](attachment:11eb2fac-1c5e-48ce-8a25-7542767b7c15.png)

# %% [markdown]
# ![image.png](attachment:ea1412fc-de1c-40b0-b9ab-1a22fd75a13e.png)

# %% [markdown]
# ![image.png](attachment:ee7bebd3-ac2c-465d-9db0-b512c7429034.png)

# %% [markdown]
# ![image.png](attachment:22d06ff9-1ddd-49f5-abd3-30be66062aea.png)

# %% [markdown]
# # **5. Умножение целых чисел**

# %% [markdown]
# ![image.png](attachment:13e3904e-6215-4352-aeba-cfe2ce6b09da.png)

# %% [markdown]
# ![image.png](attachment:a0ae5e0a-9537-49b5-b743-16edee4b2c35.png)

# %% [markdown]
# ![image.png](attachment:79f72804-f1d0-446b-809b-ac7443683c32.png)

# %% [markdown]
# ![image.png](attachment:fa61181a-c830-4f0d-8725-483055ddfed5.png)

# %% [markdown]
# ![image.png](attachment:11679bf3-5f66-46c6-80a3-2fcc2aca4d04.png)

# %% [markdown]
# ![image.png](attachment:6fe7a264-0b29-4547-a081-bf1e266905e2.png)

# %% [markdown]
# ![image.png](attachment:3d428b80-71ce-467e-a647-f730c36fc757.png)

# %% [markdown]
# ![image.png](attachment:0b083594-72ea-48c8-98e4-6a942dd8bd86.png)

# %% [markdown]
# ![image.png](attachment:3ad0dd2b-d502-45ea-946e-06794ee50387.png)

# %% [markdown]
# ![image.png](attachment:4cb9454f-8e6a-4f5a-88d4-cead644983ee.png)

# %% [markdown]
# ![image.png](attachment:7e7a3ba5-4f14-4533-9677-0adbfa9262f1.png)

# %% [markdown]
# ![image.png](attachment:43ba8255-1b34-4343-b106-677e0cc96517.png)

# %% [markdown]
# ![image.png](attachment:59126cfb-2cad-4cf8-b0c3-6850ba6b1faf.png)

# %% [markdown]
# # **6. Деление и действия с целыми числами**

# %% [markdown]
# ![image.png](attachment:687d7953-091b-48a6-b4b2-4dcb0d28cbf1.png)

# %% [markdown]
# ![image.png](attachment:b75200ff-92dd-4e60-83a3-aaf9f89c4e72.png)

# %% [markdown]
# ![image.png](attachment:8df0d9e6-7955-46d6-9084-9b632fe9045e.png)

# %% [markdown]
# ![image.png](attachment:e40cb993-1741-49fd-b7dd-25a63a91ce8b.png)

# %% [markdown]
# ![image.png](attachment:47a73c88-8570-4df2-9a4e-c8b071149766.png)

# %% [markdown]
# ![image.png](attachment:0f9a9c3d-8d77-4e86-99e8-32830e30828e.png)

# %% [markdown]
# ![image.png](attachment:cd9bff30-5ffb-437c-b981-05ade6cd8091.png)

# %% [markdown]
# ![image.png](attachment:7b933fdb-e028-4c57-9347-db9ba515d04d.png)

# %% [markdown]
# ![image.png](attachment:7ff15695-fbb6-417f-b8f0-46d29f34a481.png)

# %% [markdown]
# ![image.png](attachment:8705feb9-2f00-410a-ab6e-1fc8401446ca.png)

# %% [markdown]
# ![image.png](attachment:040bea1d-a909-446f-a99e-428e7333c5cf.png)

# %% [markdown]
# ![image.png](attachment:e1d0a8b5-281d-4a2a-9e5c-4b124d134109.png)

# %% [markdown]
# ![image.png](attachment:d9ccac8a-bc93-4c77-90bd-77d3b37f48b4.png)

# %% [markdown]
# ![image.png](attachment:15e09ef3-fc5f-4b32-9cd9-0e5f85ca28f9.png)

# %% [markdown]
# ![image.png](attachment:0844c63a-c4a2-4ae2-beb5-ce3f06fa8944.png)

# %% [markdown]
# ![image.png](attachment:f39867ef-54aa-409c-8a96-69b79d9281c0.png)

# %% [markdown]
# ![image.png](attachment:22303aee-2b38-4f07-abca-a69a3690662f.png)
