# %% [markdown]
# # **Сложение и умножение натуральных чисел**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Числа"**

# %% [markdown]
# ![image.png](attachment:c7243300-9a1c-4e23-bbba-add54eca4e88.png)

# %% [markdown]
# ![image.png](attachment:647cee75-cb1d-449b-aae1-456bb2981254.png)

# %% [markdown]
# ![image.png](attachment:395efac4-fc9e-4902-889b-00fcd4ae9e67.png)

# %% [markdown]
# ![image.png](attachment:7d2c7f57-9fcf-4492-965f-857191dff468.png)

# %% [markdown]
# # **2. Сложение и умножение натуральных чисел**

# %% [markdown]
# ![image.png](attachment:4662c165-ee55-42be-8f41-3e234ac645be.png)

# %% [markdown]
# # **2.1 Натуральные числа и ноль**

# %% [markdown]
# ![image.png](attachment:94b5e6d2-a55c-4053-bdef-8e78b245fddd.png)

# %% [markdown]
# ![image.png](attachment:d2a27494-01eb-4aa0-8b17-f60f39355732.png)

# %% [markdown]
# ![image.png](attachment:8b84e882-ab9c-47a1-bec0-5b949c7ec0ca.png)

# %% [markdown]
# ![image.png](attachment:ce8a94cd-a7da-4d33-929e-673944f495eb.png)

# %% [markdown]
# ![image.png](attachment:fa8f8910-4fda-4bbe-be14-5f0887fd7761.png)

# %% [markdown]
# ![image.png](attachment:c7182c2d-d84d-400f-8d07-3506fb3151ac.png)

# %% [markdown]
# ![image.png](attachment:7232e85b-c322-4263-9226-b7cbdfa450d6.png)

# %% [markdown]
# ![image.png](attachment:a1273092-01a0-4122-8ee3-83a627c1c4d0.png)

# %% [markdown]
# ![image.png](attachment:6642aaa5-4328-45ee-bfe5-416c7e042755.png)

# %% [markdown]
# ![image.png](attachment:3f8b327f-6b42-4858-913c-61ec982c06ab.png)

# %% [markdown]
# ![image.png](attachment:7ecb4cf7-cf11-4166-8e94-09a4fafa2ddd.png)

# %% [markdown]
# ![image.png](attachment:74d3a0f8-4164-4f29-8e7b-a6b2c093315a.png)

# %% [markdown]
# ![image.png](attachment:11acd70a-2ad8-4df4-bce7-5e50de5238ce.png)

# %% [markdown]
# ![image.png](attachment:100e7cc4-de0d-45b0-80a1-c75c3610b239.png)

# %% [markdown]
# ![image.png](attachment:ebb6ba4c-ad59-4040-8ef4-a4bb91bd8ae4.png)

# %% [markdown]
# # **2.2 Сложение и вычитание натуральных чисел**

# %% [markdown]
# ![image.png](attachment:4d8e38f8-e8de-4973-aa11-ca25a16bcfa7.png)

# %% [markdown]
# ![image.png](attachment:b92e51c1-133a-4b3e-b4dc-c69ae518197a.png)

# %% [markdown]
# ![image.png](attachment:5fbf21c9-dfd8-4df6-baca-76b8390a0719.png)

# %% [markdown]
# ![image.png](attachment:a85bb924-7148-44b9-8656-257c38138ea1.png)

# %% [markdown]
# ![image.png](attachment:23b131ee-d3b1-44de-b099-be61d554fd1c.png)

# %% [markdown]
# ![image.png](attachment:bf4360f9-e8c6-4d82-9e28-bc11b3aec0f4.png)

# %% [markdown]
# ![image.png](attachment:b855a660-b1e4-469a-afc7-9486ce6ef231.png)

# %% [markdown]
# ![image.png](attachment:feab381c-82be-4069-8df4-077d04ef3dae.png)

# %% [markdown]
# ![image.png](attachment:4409d68f-6be3-4e75-b072-f8dd0515b4e0.png)

# %% [markdown]
# ![image.png](attachment:7c516072-0934-4475-85ac-15ac40ad9ba3.png)

# %% [markdown]
# ![image.png](attachment:f152872c-28d5-4945-8dd6-b62fe3757189.png)

# %% [markdown]
# ![image.png](attachment:ec4c2c68-b52e-41a1-84d0-fe3b53e43e38.png)

# %% [markdown]
# # **2.3 Приёмы сложения и вычитания**

# %% [markdown]
# ![image.png](attachment:b174c876-aa80-45e0-9895-71dfed3adee7.png)

# %% [markdown]
# ![image.png](attachment:f97984b0-2548-44c6-8eac-47089c57b2a1.png)

# %% [markdown]
# ![image.png](attachment:ddf3a21b-8ae7-4137-a57c-93c610563ec9.png)

# %% [markdown]
# ![image.png](attachment:d64d0e04-ebd8-4ebe-bf07-1b51bcfb8570.png)

# %% [markdown]
# ![image.png](attachment:b0f2c888-5b4e-429f-a1a6-5cdbc4c42ffc.png)

# %% [markdown]
# ![image.png](attachment:1ec3ab76-d103-42cb-a494-cd1540397a33.png)

# %% [markdown]
# ![image.png](attachment:7c632e8c-402a-4480-afa4-953d259b0e0b.png)

# %% [markdown]
# ![image.png](attachment:787172f5-f7dc-4e70-9b27-3aa9cddc0880.png)

# %% [markdown]
# ![image.png](attachment:87b7fe90-c09d-4494-84a0-508b52948006.png)

# %% [markdown]
# # **2.4 Умножение и деление натуральных чисел**

# %% [markdown]
# ![image.png](attachment:cdbf2cd6-61c9-40f2-b643-b1aa74d20c65.png)

# %% [markdown]
# ![image.png](attachment:d3690c31-0b09-4597-872f-d4da8cdc5b47.png)

# %% [markdown]
# ![image.png](attachment:58931877-eff0-4ab1-8d7a-2c8eb9f0fc60.png)

# %% [markdown]
# ![image.png](attachment:1a015e3e-8d9d-4c58-aad5-5a8722efdcf9.png)

# %% [markdown]
# ![image.png](attachment:bf8489e3-84a9-45ff-8de3-c3c34ac18611.png)

# %% [markdown]
# ![image.png](attachment:c3c6873d-27a0-4cab-a995-2c08de67acf1.png)

# %% [markdown]
# ![image.png](attachment:663f1f13-daea-4c6e-91aa-1983e037e49c.png)

# %% [markdown]
# ![image.png](attachment:b765f791-c06a-427a-80d2-5c8aa50ec064.png)

# %% [markdown]
# ![image.png](attachment:c7722a31-612a-4abb-8a4a-99e64dd19d5d.png)

# %% [markdown]
# ![image.png](attachment:55e44872-8847-4051-8860-b3c85b23f05f.png)

# %% [markdown]
# ![image.png](attachment:029d2563-2b3e-4795-9d59-4cfbbf8669aa.png)

# %% [markdown]
# # **2.5 Приёмы умножения**

# %% [markdown]
# ![image.png](attachment:ebc4a010-b2b3-4b3f-8545-1c41dd425eb9.png)

# %% [markdown]
# ![image.png](attachment:410b6b77-1dc9-4ba8-b2e3-fdef5a8d5380.png)

# %% [markdown]
# ![image.png](attachment:35e13540-d837-40b3-9fd6-99d4154d5f90.png)

# %% [markdown]
# ![image.png](attachment:d07a214e-3f27-4aa3-b0f0-def7973ee791.png)

# %% [markdown]
# ![image.png](attachment:29721c67-51af-4c0a-92f2-f6a64f4333df.png)

# %% [markdown]
# ![image.png](attachment:c27a71ce-aa3b-4d83-8fc9-ecbf204a18a2.png)

# %% [markdown]
# ![image.png](attachment:ef9db32e-7ddd-446e-be73-37a1fa7efe20.png)

# %% [markdown]
# ![image.png](attachment:2b9c7637-f7df-44f7-85ec-8f4aaf52adac.png)

# %% [markdown]
# ![image.png](attachment:fb39615c-70e7-4dd0-8e4b-313e9737c461.png)

# %% [markdown]
# ![image.png](attachment:ea3d00c0-1a03-4a63-9163-9c8ccf57514f.png)

# %% [markdown]
# # **2.6 Порядок действий**

# %% [markdown]
# ![image.png](attachment:45c790a2-8af5-46b8-a966-993c4d3f864c.png)

# %% [markdown]
# ![image.png](attachment:081f0f45-cddd-47a8-88ec-2c897c66fe11.png)

# %% [markdown]
# ![image.png](attachment:12f91f87-a0aa-4e7b-b052-33ae2bf8103a.png)

# %% [markdown]
# ![image.png](attachment:e7097e36-abf9-4926-8292-8dddbd351341.png)

# %% [markdown]
# ![image.png](attachment:36dc1bfb-2fe5-4122-8e90-eee643d114c3.png)

# %% [markdown]
# ![image.png](attachment:4c296818-dd9a-4c80-86f8-c07807e11cb5.png)

# %% [markdown]
# ![image.png](attachment:d8a7a1d8-be53-4c10-8e16-4b8a47252749.png)

# %% [markdown]
# ![image.png](attachment:35622738-d29a-47af-966a-492898272d9e.png)

# %% [markdown]
# ![image.png](attachment:3c5c7f78-919b-4745-9d90-78e913f653c9.png)

# %% [markdown]
# # **2.7 Возведение в степень**

# %% [markdown]
# ![image.png](attachment:0557b0b1-cbe0-4e94-8c2a-b028bc4c45eb.png)

# %% [markdown]
# ![image.png](attachment:76ad6b85-6472-4c76-93ac-46576b03c32e.png)

# %% [markdown]
# ![image.png](attachment:b3695af5-018e-49d0-a6a3-1fe78709670a.png)

# %% [markdown]
# ![image.png](attachment:d38c5ac1-167c-42ab-865d-f0c4cac23d5d.png)

# %% [markdown]
# ![image.png](attachment:3eaa4829-a0b2-47e6-8339-0f704e3f3c67.png)

# %% [markdown]
# ![image.png](attachment:4e179cfe-ec8c-4f22-9a23-b9d9fdbafa18.png)

# %% [markdown]
# ![image.png](attachment:5cb11318-1e7c-43f4-9400-a06caf6b8570.png)

# %% [markdown]
# ![image.png](attachment:604d886b-2aff-4c30-a226-e8a581e89519.png)

# %% [markdown]
# ![image.png](attachment:4fc88bd7-39e4-412f-b510-b4a193f186bb.png)

# %% [markdown]
# # **2.8 Свойства степени**

# %% [markdown]
# ![image.png](attachment:752306b1-b70c-4ea8-89ac-092c542a9267.png)

# %% [markdown]
# ![image.png](attachment:ab03a586-c894-46ad-8178-6c0795b27320.png)

# %% [markdown]
# ![image.png](attachment:5e5c739c-b43a-41a3-8b2c-7877d7e24ae3.png)

# %% [markdown]
# ![image.png](attachment:b295f4a2-26b4-4b88-b579-92238951585c.png)

# %% [markdown]
# ![image.png](attachment:519b85a7-5158-4756-9eef-03d30929ab1a.png)

# %% [markdown]
# ![image.png](attachment:3a083f91-201c-4d80-b83c-9b3b59f24fe7.png)

# %% [markdown]
# ![image.png](attachment:c6de3e79-fcc6-4a2b-8840-75ae94805413.png)

# %% [markdown]
# ![image.png](attachment:2d183641-6ee6-4763-a897-a080a85e72a0.png)

# %% [markdown]
# ![image.png](attachment:c143c7fc-4510-47ce-bc78-8048e0946fa9.png)

# %% [markdown]
# ![image.png](attachment:04aefcf6-e6df-4cd3-88ce-28940ce92030.png)

# %% [markdown]
# # **Конспект**

# %% [markdown]
# ![image.png](attachment:bd8a0a7c-2dca-4c30-b833-95195af55aa7.png)

# %% [markdown]
# ![image.png](attachment:70a454e0-3258-4bec-a157-1eb469caa638.png)

# %% [markdown]
# ![image.png](attachment:eda56e5a-169a-4714-b36c-e927340db0b2.png)

# %% [markdown]
# ![image.png](attachment:27d48332-96b0-4c27-9bc3-64f7db5a6a06.png)

# %% [markdown]
# ![image.png](attachment:ec7cf570-aaa1-4db4-9414-a1a6757cacc3.png)

# %% [markdown]
# ![image.png](attachment:b3866fb2-4139-4253-b216-b736490a9220.png)

# %% [markdown]
# ![image.png](attachment:02525bf7-1b15-4710-9334-3d767da32f79.png)

# %% [markdown]
# ![image.png](attachment:193f7eec-3bec-44c1-9652-85933f71a204.png)

# %% [markdown]
# ![image.png](attachment:cf677dc5-8969-4380-b16e-96474bd17d08.png)

# %% [markdown]
# ![image.png](attachment:c8267aa4-4bb0-4d25-9459-980a2214a737.png)

# %% [markdown]
# ![image.png](attachment:c46628b8-0247-444f-abbc-7f43d96b1552.png)
