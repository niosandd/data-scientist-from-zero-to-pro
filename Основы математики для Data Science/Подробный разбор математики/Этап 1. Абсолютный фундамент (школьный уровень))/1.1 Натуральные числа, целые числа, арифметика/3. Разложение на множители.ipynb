# %% [markdown]
# # **Разложение на множители**

# %% [markdown]
# *За счет материалов Яндекс Практикума, который доступен по ссылке: start.practicum.yandex/math-foundations*

# %% [markdown]
# # **1. Введение к модулю "Разложение на множители"**

# %% [markdown]
# ![image.png](attachment:b90c8af7-3a03-4028-8d28-ea51eba2165a.png)

# %% [markdown]
# # **2. Простые и составные числа**

# %% [markdown]
# ![image.png](attachment:ff3d6db0-1ba8-44b4-9898-b11c4b4428e9.png)

# %% [markdown]
# ![image.png](attachment:81789b08-f218-4088-986a-19caeb7cecff.png)

# %% [markdown]
# ![image.png](attachment:202859eb-a7fd-4261-9141-156f850c1532.png)

# %% [markdown]
# ![image.png](attachment:d0819373-193f-4cc5-8942-454ab89970b8.png)

# %% [markdown]
# ![image.png](attachment:16ad5ab2-a539-41b3-8f4b-237275db133c.png)

# %% [markdown]
# ![image.png](attachment:e5502dbb-6cc3-4367-b5e7-10a4fc46b888.png)

# %% [markdown]
# ![image.png](attachment:782ef435-eb67-4fef-a7ca-a9fdba2e1cc3.png)

# %% [markdown]
# ![image.png](attachment:4c03e68e-c7e5-4f38-9700-b1f8c7376e8d.png)

# %% [markdown]
# ![image.png](attachment:068aa6b2-7f80-45aa-9c79-0f23032ba4f3.png)

# %% [markdown]
# ![image.png](attachment:bcbad468-bffe-4093-b005-1c442f649fc8.png)

# %% [markdown]
# ![image.png](attachment:43aff713-660e-489f-b941-d87b2b2fdeca.png)

# %% [markdown]
# ![image.png](attachment:dc4419a7-ce81-43cf-9cd2-b146a5c59b19.png)

# %% [markdown]
# ![image.png](attachment:85a3c8e9-e59a-4b92-9d5f-1fc96b74d93e.png)

# %% [markdown]
# ![image.png](attachment:b3774f23-bfde-431b-b09e-5274eaa2815c.png)

# %% [markdown]
# ![image.png](attachment:884d4f50-a786-40ce-b0bd-b0e7f68be9a0.png)

# %% [markdown]
# ![image.png](attachment:cfe1cfc6-9c61-4a95-9503-3ebc9270bbf1.png)

# %% [markdown]
# ![image.png](attachment:7f3173a0-0363-4533-894a-f2c1b0817a4a.png)

# %% [markdown]
# ![image.png](attachment:bca9d355-4a6f-4aaa-b875-c898d967c479.png)

# %% [markdown]
# ![image.png](attachment:1474e371-fd5e-4a0c-a30b-d598d0a0abf2.png)

# %% [markdown]
# ![image.png](attachment:c9b30339-f42b-41e9-9acd-39e7e5f32926.png)

# %% [markdown]
# # **3. Факторизация**

# %% [markdown]
# ![image.png](attachment:2785cb61-ef58-4359-b524-8946b4b7862e.png)

# %% [markdown]
# ![image.png](attachment:5d7baa15-174b-4c8a-83eb-e7e9e8ec1839.png)

# %% [markdown]
# ![image.png](attachment:ab2ee391-549d-4c3c-8173-828a00c4d185.png)

# %% [markdown]
# ![image.png](attachment:dbbb9d6c-d88f-4350-8a0f-ab19031472ab.png)

# %% [markdown]
# ![image.png](attachment:edb19a2d-804c-472a-865a-a928a1ea6f82.png)

# %% [markdown]
# ![image.png](attachment:f21d5b27-c9f4-42df-ad0c-31969912cda4.png)

# %% [markdown]
# ![image.png](attachment:459693e5-46d3-4468-a8af-3657f1f7cd2a.png)

# %% [markdown]
# ![image.png](attachment:ab1cc4c1-d0d5-4b66-ae5d-ebc4f02d7c5d.png)

# %% [markdown]
# # **4. Приёмы деления**

# %% [markdown]
# ![image.png](attachment:4f975130-cb12-4adf-8d03-309b699a1ef8.png)

# %% [markdown]
# ![image.png](attachment:eeb63c1e-5ca0-4412-9221-5c8736a015de.png)

# %% [markdown]
# ![image.png](attachment:86568787-f10c-4bb2-b9ae-272d024af8df.png)

# %% [markdown]
# ![image.png](attachment:001a21b6-4e35-4b07-8a9b-1080c899754d.png)

# %% [markdown]
# ![image.png](attachment:e3a5b4ab-b5e7-43ac-a97c-c673fd6a158f.png)

# %% [markdown]
# ![image.png](attachment:eed2f948-72cc-4888-ad1d-38f81716e693.png)

# %% [markdown]
# ![image.png](attachment:96924e74-654f-4b37-97a7-0cec2c89a162.png)

# %% [markdown]
# ![image.png](attachment:6dddb569-2844-4c63-8c6e-2d2fd497bea7.png)

# %% [markdown]
# ![image.png](attachment:df4f2edc-114a-41ae-8a3d-3d8d8e92df9b.png)

# %% [markdown]
# # **5. Деление с остатком**

# %% [markdown]
# ![image.png](attachment:ab934aad-097b-46d7-8fbf-655c40113a26.png)

# %% [markdown]
# ![image.png](attachment:a6f73f40-1a37-4ca9-8f76-ae1881dd6b27.png)

# %% [markdown]
# ![image.png](attachment:72667434-d1d4-4693-81f0-86071329db34.png)

# %% [markdown]
# ![image.png](attachment:7762a85b-2b50-45db-882a-84302f533bd8.png)

# %% [markdown]
# ![image.png](attachment:ea383e52-13df-494a-bc1b-056615cd5e72.png)

# %% [markdown]
# ![image.png](attachment:72b2d764-ee4a-452f-ae42-ea81f7131440.png)

# %% [markdown]
# ![image.png](attachment:35b60295-d59f-400e-b66c-a69390911e96.png)

# %% [markdown]
# ![image.png](attachment:46591d96-4ead-4088-9d46-d580435e9919.png)

# %% [markdown]
# ![image.png](attachment:5a10fbf3-9106-4cd0-9c02-6b9289b6141b.png)

# %% [markdown]
# ![image.png](attachment:a9a07d59-4a26-4245-abe7-14c8c7f0530b.png)

# %% [markdown]
# ![image.png](attachment:4e40b14a-0ddf-4b65-a317-2b6a8366608b.png)

# %% [markdown]
# # **6. Факториал**

# %% [markdown]
# ![image.png](attachment:bc77c720-dade-4dd0-801b-a34a360385b8.png)

# %% [markdown]
# ![image.png](attachment:d07a3e2c-55b7-43e3-a864-22b9558cb429.png)

# %% [markdown]
# ![image.png](attachment:6cbebe48-bf60-4828-9fdf-80318396003e.png)

# %% [markdown]
# ![image.png](attachment:5bd975ad-476a-4be8-82c4-abb04ac6d313.png)

# %% [markdown]
# ![image.png](attachment:e25788af-9b46-4160-8979-5d6a2475f65b.png)

# %% [markdown]
# ![image.png](attachment:09ca844f-4cab-46b0-be27-9de9a42b157b.png)

# %% [markdown]
# ![image.png](attachment:80aac5d3-85ee-4637-af25-e030a48c859a.png)

# %% [markdown]
# ![image.png](attachment:806bc987-9ae4-4558-8186-8deeff0517f5.png)

# %% [markdown]
# ![image.png](attachment:8cf7a863-55b3-4d4a-8680-458ff0bbdbf5.png)

# %% [markdown]
# ![image.png](attachment:d3dcf0ab-1d8d-490a-bc89-5366e7671767.png)

# %% [markdown]
# ![image.png](attachment:8e4105e1-1e74-4cad-ba76-0e92016a7b4b.png)

# %% [markdown]
# ![image.png](attachment:ade4e6e3-9a85-418c-a637-ee0bfcd00414.png)

# %% [markdown]
# ![image.png](attachment:fd73d567-834c-4b18-a0df-c590d5829593.png)

# %% [markdown]
# ![image.png](attachment:caa5941a-8f3a-4b28-ba10-131f96671a51.png)

# %% [markdown]
# ![image.png](attachment:7b24d1fd-f717-4528-8666-ef178fc1ca45.png)

# %% [markdown]
# ![image.png](attachment:5bd5752d-9c85-4460-86ad-d14804614d1e.png)

# %% [markdown]
# ![image.png](attachment:727bbda1-8252-41ed-b9de-75107232a1fb.png)

# %% [markdown]
# ![image.png](attachment:b2821723-aa5c-4a20-9dd7-0383c489951a.png)

# %% [markdown]
# ![image.png](attachment:88878ee6-713a-487a-a689-68822dc8d4d1.png)

# %% [markdown]
# ![image.png](attachment:0c94db24-5e14-478d-a6b5-2362dc9ddc23.png)

# %% [markdown]
# ![image.png](attachment:fd76d24d-b266-4ea5-809e-09563297e79f.png)

# %% [markdown]
# ![image.png](attachment:96cf7af3-34e7-49b7-8925-8e8552483990.png)

# %% [markdown]
# ![image.png](attachment:8ce07e39-64ad-463e-9cf9-b93a78c3a838.png)

# %% [markdown]
# ![image.png](attachment:1c9dda49-1022-468a-9cc2-66dbf784ebfd.png)

# %% [markdown]
# ![image.png](attachment:69aae882-d85f-410e-963c-a5967398725a.png)

# %% [markdown]
# ![image.png](attachment:edab8251-50eb-411e-a503-67122979c6a0.png)

# %% [markdown]
# ![image.png](attachment:6fc36791-cca6-4dc7-923a-c120d8f65e6d.png)

# %% [markdown]
# ![image.png](attachment:375059bb-f11d-4a8a-8bc0-e9d679b9f4ba.png)

# %% [markdown]
# ![image.png](attachment:0b3e0fa9-0446-4496-aea8-bf7f27088f52.png)

# %% [markdown]
# ![image.png](attachment:9b56907f-30c1-4800-bb52-5e594179e510.png)
